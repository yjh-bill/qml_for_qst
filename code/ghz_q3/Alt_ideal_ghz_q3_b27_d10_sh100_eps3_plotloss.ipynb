# %%
import os
from math import pi
import numpy as np
import random
import itertools
import scipy.optimize as opt
import matplotlib.pyplot as plt
import qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
# from qiskit_aer.noise import NoiseModel
# from qiskit_ibm_provider import IBMProvider

# %%
shots = 100
epsilon_loss = 1e-3 # loss added if test_counts entry is not found
epsilon_parameters=0.1 # scaling factor for initial random parameters (chosen between 0 to 2pi otherwise)

n_qubits = 3
n_bases = 27
depth = 10

max_iter = 1000

param_name = "theta"

# save checkpoints in case the connection to qpu breaks
# useful for running on real qpu, but not necessary for local simulation
have_checkpoints = False
checkpoint_path = "Alt_ideal_ghz_q3_b27_d6_sh100_checkpoints"

seed = None
trial = '_plot'

# %%
# random.seed(seed)
# rng = np.random.default_rng(seed)
rng = np.random.default_rng()

# %%
# if have_checkpoints:
#     os.mkdir(checkpoint_path)

# %%
# backend = AerSimulator()
# sampler = Sampler.from_backend(backend)
# pm = generate_preset_pass_manager(backend=backend)

simulator_ideal = AerSimulator()
simulator_ideal.set_options(seed_simulator=seed)
# sampler_ideal = Sampler.from_backend(simulator_ideal)
pm_ideal = generate_preset_pass_manager(backend=simulator_ideal, optimization_level=1)

# sampler = sampler_ideal
pm = pm_ideal

# %%
def create_ghz_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n - 1):
        qc.cx(i, i + 1)
    return qc

def get_circ_for_basis(qc: QuantumCircuit, basis: str):
    circ = qc.copy()
    for i, s in enumerate(basis[::-1]): # here, I am using the same endian convention as qiskit, where the last bit represent the first qubit
        if s == 'Z':
            pass
        elif s == 'X':
            circ.ry(-pi/2, i)
        elif s == 'Y':
            circ.rx(pi/2, i)
        else:
            raise ValueError(f"{s} is invalid basis")

    circ.measure_all()

    return circ

def get_isa_circ_list_for_bases(qc: QuantumCircuit, basis_list, pass_manager):
    circ_list = [get_circ_for_basis(qc, basis) for basis in basis_list]
    isa_circ_list = pass_manager.run(circ_list)
    return isa_circ_list


def measure_isa_circ_list_fs(isa_circ_list, basis_list, shots=shots):
    sampler = Sampler()
    result_list = sampler.run(isa_circ_list, shots=shots).result()
    counts_list = [result.data.meas.get_counts() for result in result_list]
    results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    return results_dic


def get_basis_list(n_bases,n_qubits):
    bases = ["X", "Y", "Z"]
    basis_list = ["".join(p) for p in itertools.product(bases, repeat=n_qubits)]
    culled_basis_list = random.sample(basis_list, n_bases)
    return culled_basis_list




# def measure_circ_for_all_basis(qc, basis_list, shots=total_shots, sampler=None):
#     results_dic = {}
#     qc_list = [get_circ_for_basis(qc, basis, simulator) for basis in basis_list]
#     job = simulator.run(qc_list, shots=shots)
#     result = job.result()
#     counts_list = result.get_counts()
#     results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    
#     return results_dic

# %%
basis_list = get_basis_list(n_bases, n_qubits)
# %%
def initialize_theta_random(circ_depth=10, num_qbits=3):
    """
    Initialize the theta parameter vector
    :param circ_depth: int, number of parameterized layers in circuit
    :param num_qbits: int, number of qbits
    :return: np.array, values of theta
    """

    theta = rng.random(size=(circ_depth, num_qbits))
    theta = 2*pi*epsilon_parameters*theta
    return theta

# %%
def construct_variational_circ_ansatz(num_qbits, circ_depth, param_name = param_name):
    """
    Generate a parameterized variational quantum circuit
    
    """

    num_parameters = num_qbits * circ_depth
    theta_vec = ParameterVector(param_name, length=num_parameters)
    var_circ = QuantumCircuit(num_qbits)


    for layer in range(circ_depth - 1):
        # Compute if layer is odd or even to apply rx or ry gate to circuit
        is_odd_step = (layer + 1) % 2

        for qbit in range(num_qbits):
            if is_odd_step:
                var_circ.rx(theta_vec[layer * num_qbits + qbit], qbit)
            else:
                var_circ.ry(theta_vec[layer * num_qbits + qbit], qbit)

        # Apply CX gates
        for qbit in range((1-is_odd_step), num_qbits-1, 2):
            # isOddStep may subtract 1 if True, to correctly apply cx gate location
            var_circ.cx(qbit , qbit + 1)
            var_circ.barrier() # for visualization only

    for qbit in range(num_qbits):  # bonus layer at the end only has rx gates and no cx
        var_circ.rx(theta_vec[(circ_depth - 1) * num_qbits + qbit], qbit)

    return var_circ, theta_vec

# %%
ansatz, param_vec = construct_variational_circ_ansatz(n_qubits, depth, param_name=param_name)

# %%
ansatz.draw(output="mpl", style="clifford")

# %%
ansatz_isa_list = get_isa_circ_list_for_bases(ansatz, basis_list, pm)

# %%
def get_ansatz_output(ansatz_isa_list, parameters, basis_list, shots, param_placeholder=param_vec):
    circ_run_list = [circ.assign_parameters({param_placeholder:parameters}) for circ in ansatz_isa_list]
    return measure_isa_circ_list_fs(isa_circ_list=circ_run_list, basis_list=basis_list, shots=shots)

# %%
def KL_divergence(true_data, test_data, epsilon_loss = epsilon_loss):
    loss = 0

    # here, let me assume true data and test data can have different number of shots
    # but the shot in each basis should be the same
    true_data_total_shots = sum(list(true_data.values())[0].values())
    test_data_total_shots = sum(list(test_data.values())[0].values())

    for basis in true_data: # just a note that if there are hallucinated measurements in 
        # bases/states not included in the true data then the kl divergence will not account for these (at least as presented in the paper)
        for state in true_data[basis]:
            true_counts = true_data[basis][state]
            test_counts = test_data[basis].get(state, 0)
            true_prob   = true_counts / true_data_total_shots
            test_prob   = test_counts / test_data_total_shots
            loss += true_prob *(np.log((true_prob)/(test_prob +epsilon_loss)))

    return loss / len(true_data)

# %%
global loss_values
global thetas

loss_values = []
thetas = []

# %%
def compute_kl_loss(theta_vector, ansatz_isa_list,  basis_list, true_data, shots, param_placeholder=param_vec, \
        print_message=True, have_checkpoints=have_checkpoints, checkpoint_path=checkpoint_path):
    # theta = np.reshape(theta_vector, (circ_depth, num_qbits))
    # tempcirc = construct_variational_circ(theta=theta)
    test_data = get_ansatz_output(ansatz_isa_list=ansatz_isa_list, parameters=theta_vector, basis_list=basis_list, \
        shots=shots, param_placeholder=param_placeholder)
    # test_data = measure_circ_for_all_basis(qc = tempcirc, basis_list=basis_list, simulator=simulator)
    loss = KL_divergence(true_data, test_data) + \
        KL_divergence(test_data, true_data) # symmetrizing the loss

    global loss_values
    global thetas 
    loss_values.append(loss)
    thetas.append(theta_vector)

    num_iter = len(loss_values)

    if print_message:
        print(f"Iteration {num_iter:5}; current loss is {loss}")

    if have_checkpoints:
        # save checkpoints in case the connection to qpu breaks
        # useful for running on real qpu, but not necessary for local simulation
        np.save(os.path.join(checkpoint_path, f"theta_iter{num_iter}.npy"), thetas)
    
    return loss

# %%
from qiskit_algorithms.optimizers import SPSA

spsa = SPSA()
print(spsa.is_initial_point_ignored)
# Out:
# False

# %%
# wraps the function with the all arguments but theta vector already filled

def compute_kl_loss_filled(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec, print_message=True)

def compute_kl_loss_filled_quiet(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec, print_message=False)

# %%
loss_proper_values = [] # the loss function L(theta)
# by contrast, if we do not use the callback, we get L(theta+-deltaTheta) instead in SPSA algorithm


def callback(nev, x, fx, a, flag):
    print(f"Number of call {nev:5}; current loss is {fx}")
    loss_proper_values.append(fx)

# %%
# %%time

theta = initialize_theta_random(circ_depth=depth, num_qbits = n_qubits)
theta_vector = np.reshape(theta, theta.size)
circ_depth, num_qbits = theta.shape

spsa = SPSA(maxiter=300, callback=callback)
c=0.1258
A=0.3186
a1=0.4739
alpha=0.6374
gamma=0.06059
(lr, p) = spsa.calibrate(compute_kl_loss_filled, theta_vector, c=c, stability_constant = A, target_magnitude=a1, alpha=alpha, gamma=gamma)
spsa.learning_rate = lr
spsa.perturbation = p

args = (ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec)

# results = opt.minimize(compute_kl_loss, theta_vector, args = args, method = "Powell", options={"maxiter":max_iter})

results = spsa.minimize(compute_kl_loss_filled, theta_vector)
# Out:
# Iteration     1; current loss is 2.4004712232428695
# Iteration     2; current loss is 2.3044060655972083
# Iteration     3; current loss is 2.209921426416469
# Iteration     4; current loss is 2.367149413015148
# Iteration     5; current loss is 2.2748301079928623
# Iteration     6; current loss is 2.5595068911469134
# Iteration     7; current loss is 2.331618338257991
# Iteration     8; current loss is 2.075436564707131
# Iteration     9; current loss is 2.3649695830466984
# Iteration    10; current loss is 2.2331607526729353
# Iteration    11; current loss is 2.7281636359131465
# Iteration    12; current loss is 2.1247281032804612
# Iteration    13; current loss is 2.3577337424583127
# Iteration    14; current loss is 2.327184188372339
# Iteration    15; current loss is 2.341667150181669
# Iteration    16; current loss is 2.2963176365499605
# Iteration    17; current loss is 2.2079562691529264
# Iteration    18; current loss is 2.7187485483275546
# Iteration    19; current loss is 2.478217978982462
# Iteration    20; current loss is 2.2276688087613667
# Iteration    21; current loss is 2.2155446473996165
# Iteration    22; current loss is 2.4684095614370074
# Iteration    23; current loss is 2.1888958236733016
# Iteration    24; current loss is 2.2089896304157164
# Iteration    25; current loss is 2.10321038294514
# Iteration    26; current loss is 2.383009916293364
# Iteration    27; current loss is 2.3384839956925605
# Iteration    28; current loss is 2.341634235948812
# Iteration    29; current loss is 2.587186611725498
# Iteration    30; current loss is 2.2415846896769542
# Iteration    31; current loss is 2.266002470256368
# Iteration    32; current loss is 2.4407377479056276
# Iteration    33; current loss is 2.4606634554117397
# Iteration    34; current loss is 2.453850149280129
# Iteration    35; current loss is 2.2326097054041423
# Iteration    36; current loss is 2.3248267705851555
# Iteration    37; current loss is 2.4731247394945166
# Iteration    38; current loss is 2.405791630109065
# Iteration    39; current loss is 2.2064921346334674
# Iteration    40; current loss is 2.461627185803846
# Iteration    41; current loss is 1.9835616771066438
# Iteration    42; current loss is 2.570751891611386
# Iteration    43; current loss is 2.3925637349405147
# Iteration    44; current loss is 2.5197864243138177
# Iteration    45; current loss is 2.0973566554290333
# Iteration    46; current loss is 2.455395032732194
# Iteration    47; current loss is 2.265177124260467
# Iteration    48; current loss is 2.595391971885249
# Iteration    49; current loss is 2.4498565527398375
# Iteration    50; current loss is 2.5016932557664457
# Iteration    51; current loss is 2.491102008498717
# Iteration    52; current loss is 2.0280056935005373
# Iteration    53; current loss is 2.6253278422810675
# Number of call     3; current loss is 2.6253278422810675
# Iteration    54; current loss is 2.626270986365424
# Iteration    55; current loss is 2.4941160134866767
# Iteration    56; current loss is 2.4952209350866426
# Number of call     6; current loss is 2.4952209350866426
# Iteration    57; current loss is 2.462736856885248
# Iteration    58; current loss is 2.3755769481855036
# Iteration    59; current loss is 2.5295248757039586
# Number of call     9; current loss is 2.5295248757039586
# Iteration    60; current loss is 2.6249606279509
# Iteration    61; current loss is 2.3020259011402997
# Iteration    62; current loss is 2.0092513981662132
# Number of call    12; current loss is 2.0092513981662132
# Iteration    63; current loss is 1.813263081338249
# Iteration    64; current loss is 2.014400114780484
# Iteration    65; current loss is 1.903378993232208
# Number of call    15; current loss is 1.903378993232208
# Iteration    66; current loss is 1.881987749080178
# Iteration    67; current loss is 1.9769692458829449
# Iteration    68; current loss is 1.9212142695798637
# Number of call    18; current loss is 1.9212142695798637
# Iteration    69; current loss is 1.9252002435025743
# Iteration    70; current loss is 2.0994838576622747
# Iteration    71; current loss is 1.9033035536952068
# Number of call    21; current loss is 1.9033035536952068
# Iteration    72; current loss is 1.931550948833611
# Iteration    73; current loss is 1.8589208416674778
# Iteration    74; current loss is 1.8410855599122056
# Number of call    24; current loss is 1.8410855599122056
# Iteration    75; current loss is 1.9260516231313554
# Iteration    76; current loss is 1.8862303579836122
# Iteration    77; current loss is 1.8274673248189686
# Number of call    27; current loss is 1.8274673248189686
# Iteration    78; current loss is 2.193055952083643
# Iteration    79; current loss is 1.6854837075471218
# Iteration    80; current loss is 2.109545572812179
# Number of call    30; current loss is 2.109545572812179
# Iteration    81; current loss is 2.1351138136535233
# Iteration    82; current loss is 1.9902886710369518
# Iteration    83; current loss is 1.8717393792548576
# Number of call    33; current loss is 1.8717393792548576
# Iteration    84; current loss is 2.167792444746339
# Iteration    85; current loss is 1.541666053971469
# Iteration    86; current loss is 1.6786826364701564
# Number of call    36; current loss is 1.6786826364701564
# Iteration    87; current loss is 1.5380298876773995
# Iteration    88; current loss is 1.8630988434759197
# Iteration    89; current loss is 1.6723513613554946
# Number of call    39; current loss is 1.6723513613554946
# Iteration    90; current loss is 1.4951130619894502
# Iteration    91; current loss is 1.6050899444488653
# Iteration    92; current loss is 1.6113563583797355
# Number of call    42; current loss is 1.6113563583797355
# Iteration    93; current loss is 1.54417369868869
# Iteration    94; current loss is 1.8609748649997906
# Iteration    95; current loss is 1.7069112994082718
# Number of call    45; current loss is 1.7069112994082718
# Iteration    96; current loss is 1.8725520130820488
# Iteration    97; current loss is 1.5569734126781518
# Iteration    98; current loss is 1.5652131895966512
# Number of call    48; current loss is 1.5652131895966512
# Iteration    99; current loss is 1.9392570186139908
# Iteration   100; current loss is 1.192748654506758
# Iteration   101; current loss is 0.9728970270587958
# Number of call    51; current loss is 0.9728970270587958
# Iteration   102; current loss is 1.3010328151371198
# Iteration   103; current loss is 0.8083050138501776
# Iteration   104; current loss is 0.8901017575521335
# Number of call    54; current loss is 0.8901017575521335
# Iteration   105; current loss is 0.950865845070697
# Iteration   106; current loss is 1.155228971812505
# Iteration   107; current loss is 0.9344086726841031
# Number of call    57; current loss is 0.9344086726841031
# Iteration   108; current loss is 0.9375008770868645
# Iteration   109; current loss is 1.1073111092845644
# Iteration   110; current loss is 0.8689860127630349
# Number of call    60; current loss is 0.8689860127630349
# Iteration   111; current loss is 1.1290794160088669
# Iteration   112; current loss is 1.0117356109227567
# Iteration   113; current loss is 1.0071535673438279
# Number of call    63; current loss is 1.0071535673438279
# Iteration   114; current loss is 0.9502024055372966
# Iteration   115; current loss is 1.1582066256716423
# Iteration   116; current loss is 0.8571922638222569
# Number of call    66; current loss is 0.8571922638222569
# Iteration   117; current loss is 1.1331764684078303
# Iteration   118; current loss is 0.8739112634719752
# Iteration   119; current loss is 0.9122033378295121
# Number of call    69; current loss is 0.9122033378295121
# Iteration   120; current loss is 0.8625167146832811
# Iteration   121; current loss is 1.2936887110996995
# Iteration   122; current loss is 1.0246921924160368
# Number of call    72; current loss is 1.0246921924160368
# Iteration   123; current loss is 1.4244032275144192
# Iteration   124; current loss is 0.8356828091617196
# Iteration   125; current loss is 0.9507768778643922
# Number of call    75; current loss is 0.9507768778643922
# Iteration   126; current loss is 1.005077204335878
# Iteration   127; current loss is 0.8730873836448312
# Iteration   128; current loss is 0.8523987801784803
# Number of call    78; current loss is 0.8523987801784803
# Iteration   129; current loss is 0.9518528717743584
# Iteration   130; current loss is 1.010495380463659
# Iteration   131; current loss is 0.9126716968691282
# Number of call    81; current loss is 0.9126716968691282
# Iteration   132; current loss is 1.3322322131526818
# Iteration   133; current loss is 0.7921811860565957
# Iteration   134; current loss is 0.9457438486831916
# Number of call    84; current loss is 0.9457438486831916
# Iteration   135; current loss is 1.498640137104506
# Iteration   136; current loss is 0.8917034725711424
# Iteration   137; current loss is 1.0208313032096776
# Number of call    87; current loss is 1.0208313032096776
# Iteration   138; current loss is 1.273004540222333
# Iteration   139; current loss is 1.0676455325396894
# Iteration   140; current loss is 0.933831437998512
# Number of call    90; current loss is 0.933831437998512
# Iteration   141; current loss is 0.840767159373895
# Iteration   142; current loss is 1.3333085481250055
# Iteration   143; current loss is 0.9170352865701092
# Number of call    93; current loss is 0.9170352865701092
# Iteration   144; current loss is 1.0190085084934335
# Iteration   145; current loss is 0.9141413692950076
# Iteration   146; current loss is 0.8427358241355554
# Number of call    96; current loss is 0.8427358241355554
# Iteration   147; current loss is 1.0712588555735536
# Iteration   148; current loss is 0.8722214095831238
# Iteration   149; current loss is 0.8629067744767742
# Number of call    99; current loss is 0.8629067744767742
# Iteration   150; current loss is 0.8877312545248423
# Iteration   151; current loss is 0.9651815843391574
# Iteration   152; current loss is 0.8047861546387747
# Number of call   102; current loss is 0.8047861546387747
# Iteration   153; current loss is 0.9110864444167228
# Iteration   154; current loss is 1.0830573449227652
# Iteration   155; current loss is 0.8657186590484156
# Number of call   105; current loss is 0.8657186590484156
# Iteration   156; current loss is 0.7894683949752821
# Iteration   157; current loss is 1.0183758272145242
# Iteration   158; current loss is 0.8684783822378477
# Number of call   108; current loss is 0.8684783822378477
# Iteration   159; current loss is 1.0225916489281257
# Iteration   160; current loss is 0.9005875097668825
# Iteration   161; current loss is 0.8717356889983612
# Number of call   111; current loss is 0.8717356889983612
# Iteration   162; current loss is 0.7475267802538137
# Iteration   163; current loss is 1.1398508900878335
# Iteration   164; current loss is 0.852849236464964
# Number of call   114; current loss is 0.852849236464964
# Iteration   165; current loss is 0.9593080998768263
# Iteration   166; current loss is 0.9840677262874906
# Iteration   167; current loss is 0.9696797941251759
# Number of call   117; current loss is 0.9696797941251759
# Iteration   168; current loss is 0.8924471215285169
# Iteration   169; current loss is 0.9543308351152894
# Iteration   170; current loss is 0.8782054259238621
# Number of call   120; current loss is 0.8782054259238621
# Iteration   171; current loss is 0.9952253653742864
# Iteration   172; current loss is 0.9660851523697269
# Iteration   173; current loss is 0.8315814005601302
# Number of call   123; current loss is 0.8315814005601302
# Iteration   174; current loss is 1.2270483841254136
# Iteration   175; current loss is 0.8030621697190654
# Iteration   176; current loss is 0.8184406450229083
# Number of call   126; current loss is 0.8184406450229083
# Iteration   177; current loss is 1.049233555279502
# Iteration   178; current loss is 0.7388713207784365
# Iteration   179; current loss is 0.7296997721487641
# Number of call   129; current loss is 0.7296997721487641
# Iteration   180; current loss is 0.7140567681679563
# Iteration   181; current loss is 1.0030469659283034
# Iteration   182; current loss is 0.7095086933141791
# Number of call   132; current loss is 0.7095086933141791
# Iteration   183; current loss is 0.8745023883069065
# Iteration   184; current loss is 0.7565920698778008
# Iteration   185; current loss is 0.7039981761680297
# Number of call   135; current loss is 0.7039981761680297
# Iteration   186; current loss is 1.1722025155116373
# Iteration   187; current loss is 0.4789474411848554
# Iteration   188; current loss is 0.5940434500913803
# Number of call   138; current loss is 0.5940434500913803
# Iteration   189; current loss is 0.8533826638944199
# Iteration   190; current loss is 0.7691998287918511
# Iteration   191; current loss is 0.5686030420704159
# Number of call   141; current loss is 0.5686030420704159
# Iteration   192; current loss is 1.062828734825197
# Iteration   193; current loss is 0.7146963157313344
# Iteration   194; current loss is 0.6521819914035265
# Number of call   144; current loss is 0.6521819914035265
# Iteration   195; current loss is 0.7605166724657251
# Iteration   196; current loss is 0.8227186320398181
# Iteration   197; current loss is 0.75570302674761
# Number of call   147; current loss is 0.75570302674761
# Iteration   198; current loss is 0.7721911438064244
# Iteration   199; current loss is 0.8045746003443652
# Iteration   200; current loss is 0.6157208626366264
# Number of call   150; current loss is 0.6157208626366264
# Iteration   201; current loss is 0.7392032067667036
# Iteration   202; current loss is 0.850938720613084
# Iteration   203; current loss is 0.6357647028360265
# Number of call   153; current loss is 0.6357647028360265
# Iteration   204; current loss is 1.0138135505500951
# Iteration   205; current loss is 0.6829027292344203
# Iteration   206; current loss is 0.59692103435755
# Number of call   156; current loss is 0.59692103435755
# Iteration   207; current loss is 0.8470854801865866
# Iteration   208; current loss is 0.5671431967980176
# Iteration   209; current loss is 0.5269523157116256
# Number of call   159; current loss is 0.5269523157116256
# Iteration   210; current loss is 0.4926098947780092
# Iteration   211; current loss is 0.9245758102145112
# Iteration   212; current loss is 0.5196979849271777
# Number of call   162; current loss is 0.5196979849271777
# Iteration   213; current loss is 0.4952793367960594
# Iteration   214; current loss is 0.7369289962403363
# Iteration   215; current loss is 0.45628896634462895
# Number of call   165; current loss is 0.45628896634462895
# Iteration   216; current loss is 0.5006738961314953
# Iteration   217; current loss is 0.594968431620235
# Iteration   218; current loss is 0.4138441267798465
# Number of call   168; current loss is 0.4138441267798465
# Iteration   219; current loss is 0.6898054857111642
# Iteration   220; current loss is 0.4764565136829942
# Iteration   221; current loss is 0.4043543004803714
# Number of call   171; current loss is 0.4043543004803714
# Iteration   222; current loss is 0.4974811722690079
# Iteration   223; current loss is 0.5378172423622808
# Iteration   224; current loss is 0.41926483544989446
# Number of call   174; current loss is 0.41926483544989446
# Iteration   225; current loss is 0.8764283467822416
# Iteration   226; current loss is 0.45574856266023933
# Iteration   227; current loss is 0.4538474872383139
# Number of call   177; current loss is 0.4538474872383139
# Iteration   228; current loss is 0.5787984470263445
# Iteration   229; current loss is 0.38177513785486317
# Iteration   230; current loss is 0.4213991933101362
# Number of call   180; current loss is 0.4213991933101362
# Iteration   231; current loss is 0.4646465846080454
# Iteration   232; current loss is 0.6637696056395026
# Iteration   233; current loss is 0.39521385564814693
# Number of call   183; current loss is 0.39521385564814693
# Iteration   234; current loss is 0.6331563733653927
# Iteration   235; current loss is 0.42072577059386335
# Iteration   236; current loss is 0.3694838855003313
# Number of call   186; current loss is 0.3694838855003313
# Iteration   237; current loss is 0.5028842313344509
# Iteration   238; current loss is 0.5908158904592928
# Iteration   239; current loss is 0.4220277358107578
# Number of call   189; current loss is 0.4220277358107578
# Iteration   240; current loss is 0.4047093684771794
# Iteration   241; current loss is 0.4936377969861861
# Iteration   242; current loss is 0.3702421360501359
# Number of call   192; current loss is 0.3702421360501359
# Iteration   243; current loss is 0.4306916330071685
# Iteration   244; current loss is 0.38357357195228003
# Iteration   245; current loss is 0.36762721493071415
# Number of call   195; current loss is 0.36762721493071415
# Iteration   246; current loss is 0.9325516179705495
# Iteration   247; current loss is 0.4411721230907909
# Iteration   248; current loss is 0.4411092017461396
# Number of call   198; current loss is 0.4411092017461396
# Iteration   249; current loss is 0.49954135741984557
# Iteration   250; current loss is 1.2156145432249685
# Iteration   251; current loss is 0.7410194058224808
# Number of call   201; current loss is 0.7410194058224808
# Iteration   252; current loss is 0.8545859833303671
# Iteration   253; current loss is 1.016927028015722
# Iteration   254; current loss is 0.6572228488297059
# Number of call   204; current loss is 0.6572228488297059
# Iteration   255; current loss is 0.6738197373041095
# Iteration   256; current loss is 1.2331872111459674
# Iteration   257; current loss is 0.5796544333444605
# Number of call   207; current loss is 0.5796544333444605
# Iteration   258; current loss is 0.7205232286310748
# Iteration   259; current loss is 0.5944544246857937
# Iteration   260; current loss is 0.5891280881905114
# Number of call   210; current loss is 0.5891280881905114
# Iteration   261; current loss is 0.6045983463958371
# Iteration   262; current loss is 0.6887969095021467
# Iteration   263; current loss is 0.6190844353039044
# Number of call   213; current loss is 0.6190844353039044
# Iteration   264; current loss is 0.4484116700120584
# Iteration   265; current loss is 0.9021222645106823
# Iteration   266; current loss is 0.46077284185827705
# Number of call   216; current loss is 0.46077284185827705
# Iteration   267; current loss is 0.5293331715294899
# Iteration   268; current loss is 0.5411947881983068
# Iteration   269; current loss is 0.4837871487430384
# Number of call   219; current loss is 0.4837871487430384
# Iteration   270; current loss is 0.8300086701812927
# Iteration   271; current loss is 0.37928510880481536
# Iteration   272; current loss is 0.3557762166500753
# Number of call   222; current loss is 0.3557762166500753
# Iteration   273; current loss is 0.5665619593275548
# Iteration   274; current loss is 0.36978440651646727
# Iteration   275; current loss is 0.34384047850856514
# Number of call   225; current loss is 0.34384047850856514
# Iteration   276; current loss is 0.5202224082515389
# Iteration   277; current loss is 0.4083426723886546
# Iteration   278; current loss is 0.3358382729953821
# Number of call   228; current loss is 0.3358382729953821
# Iteration   279; current loss is 0.5478765041051868
# Iteration   280; current loss is 0.5071034540844951
# Iteration   281; current loss is 0.3041459307511721
# Number of call   231; current loss is 0.3041459307511721
# Iteration   282; current loss is 0.4706301893030028
# Iteration   283; current loss is 0.388815478125879
# Iteration   284; current loss is 0.3161630825518521
# Number of call   234; current loss is 0.3161630825518521
# Iteration   285; current loss is 0.48260417459335947
# Iteration   286; current loss is 0.4165063257406306
# Iteration   287; current loss is 0.30821359341192045
# Number of call   237; current loss is 0.30821359341192045
# Iteration   288; current loss is 0.35629400973707126
# Iteration   289; current loss is 0.40443767323779306
# Iteration   290; current loss is 0.32502262592104203
# Number of call   240; current loss is 0.32502262592104203
# Iteration   291; current loss is 0.4501901838001001
# Iteration   292; current loss is 0.31295898785139875
# Iteration   293; current loss is 0.33928051378657154
# Number of call   243; current loss is 0.33928051378657154
# Iteration   294; current loss is 0.41871051262086423
# Iteration   295; current loss is 0.3955061462177656
# Iteration   296; current loss is 0.32587043032003676
# Number of call   246; current loss is 0.32587043032003676
# Iteration   297; current loss is 0.534122522791669
# Iteration   298; current loss is 0.23131505266507746
# Iteration   299; current loss is 0.22932521878439488
# Number of call   249; current loss is 0.22932521878439488
# Iteration   300; current loss is 0.28208046688024035
# Iteration   301; current loss is 0.5142001313030908
# Iteration   302; current loss is 0.2801935733146473
# Number of call   252; current loss is 0.2801935733146473
# Iteration   303; current loss is 0.4654289405592955
# Iteration   304; current loss is 0.32368927085627086
# Iteration   305; current loss is 0.25574750392071993
# Number of call   255; current loss is 0.25574750392071993
# Iteration   306; current loss is 0.34991745272894326
# Iteration   307; current loss is 0.29379521554791266
# Iteration   308; current loss is 0.2195954815745431
# Number of call   258; current loss is 0.2195954815745431
# Iteration   309; current loss is 0.505447227592182
# Iteration   310; current loss is 0.2648170306125268
# Iteration   311; current loss is 0.2074587754355094
# Number of call   261; current loss is 0.2074587754355094
# Iteration   312; current loss is 0.3772286196275511
# Iteration   313; current loss is 0.3187397431264146
# Iteration   314; current loss is 0.2309622901986595
# Number of call   264; current loss is 0.2309622901986595
# Iteration   315; current loss is 0.43332830277429774
# Iteration   316; current loss is 0.3950437746915335
# Iteration   317; current loss is 0.2383760808887202
# Number of call   267; current loss is 0.2383760808887202
# Iteration   318; current loss is 0.33524607825585573
# Iteration   319; current loss is 0.40685159384844694
# Iteration   320; current loss is 0.19710212901895774
# Number of call   270; current loss is 0.19710212901895774
# Iteration   321; current loss is 0.2404716883854932
# Iteration   322; current loss is 0.4897099820562866
# Iteration   323; current loss is 0.21247711971517452
# Number of call   273; current loss is 0.21247711971517452
# Iteration   324; current loss is 0.2496143764115989
# Iteration   325; current loss is 0.3902628032182363
# Iteration   326; current loss is 0.17427774717382155
# Number of call   276; current loss is 0.17427774717382155
# Iteration   327; current loss is 0.44508005456819916
# Iteration   328; current loss is 0.20753139841521417
# Iteration   329; current loss is 0.17980475854205213
# Number of call   279; current loss is 0.17980475854205213
# Iteration   330; current loss is 0.2498494664255751
# Iteration   331; current loss is 0.3313180953721242
# Iteration   332; current loss is 0.17957012611569534
# Number of call   282; current loss is 0.17957012611569534
# Iteration   333; current loss is 0.18695388913749295
# Iteration   334; current loss is 0.3279476049998612
# Iteration   335; current loss is 0.19217426933205484
# Number of call   285; current loss is 0.19217426933205484
# Iteration   336; current loss is 0.2591862124550217
# Iteration   337; current loss is 0.33977319192501587
# Iteration   338; current loss is 0.17931731572268658
# Number of call   288; current loss is 0.17931731572268658
# Iteration   339; current loss is 0.24781356160083468
# Iteration   340; current loss is 0.32195799398392255
# Iteration   341; current loss is 0.18984665311429563
# Number of call   291; current loss is 0.18984665311429563
# Iteration   342; current loss is 0.22924784981197083
# Iteration   343; current loss is 0.2130939200177921
# Iteration   344; current loss is 0.15842325388171236
# Number of call   294; current loss is 0.15842325388171236
# Iteration   345; current loss is 0.4754953036819191
# Iteration   346; current loss is 0.5703521901161069
# Iteration   347; current loss is 0.15948528233615278
# Number of call   297; current loss is 0.15948528233615278
# Iteration   348; current loss is 0.32394220354270303
# Iteration   349; current loss is 0.24877378656544064
# Iteration   350; current loss is 0.1626977896804337
# Number of call   300; current loss is 0.1626977896804337
# Iteration   351; current loss is 0.32149242979648895
# Iteration   352; current loss is 0.3033375862505617
# Iteration   353; current loss is 0.16611577933966512
# Number of call   303; current loss is 0.16611577933966512
# Iteration   354; current loss is 0.23142366694496955
# Iteration   355; current loss is 0.240863930232675
# Iteration   356; current loss is 0.1613417991863727
# Number of call   306; current loss is 0.1613417991863727
# Iteration   357; current loss is 0.35321126878274145
# Iteration   358; current loss is 0.3153240266555447
# Iteration   359; current loss is 0.1511834562637724
# Number of call   309; current loss is 0.1511834562637724
# Iteration   360; current loss is 0.5019539946138355
# Iteration   361; current loss is 0.38987751718110164
# Iteration   362; current loss is 0.17182971550972548
# Number of call   312; current loss is 0.17182971550972548
# Iteration   363; current loss is 0.28489904828985646
# Iteration   364; current loss is 0.32926620958019404
# Iteration   365; current loss is 0.15787681133616496
# Number of call   315; current loss is 0.15787681133616496
# Iteration   366; current loss is 0.3471576441664105
# Iteration   367; current loss is 0.2712146608799033
# Iteration   368; current loss is 0.1473463604858647
# Number of call   318; current loss is 0.1473463604858647
# Iteration   369; current loss is 0.3371194547937544
# Iteration   370; current loss is 0.29068876957674095
# Iteration   371; current loss is 0.13004068037832703
# Number of call   321; current loss is 0.13004068037832703
# Iteration   372; current loss is 0.5014723770361711
# Iteration   373; current loss is 0.2724696263208483
# Iteration   374; current loss is 0.17652307344377516
# Number of call   324; current loss is 0.17652307344377516
# Iteration   375; current loss is 0.2552005627161554
# Iteration   376; current loss is 0.3243945609471841
# Iteration   377; current loss is 0.17462579535962794
# Number of call   327; current loss is 0.17462579535962794
# Iteration   378; current loss is 0.38937527132796357
# Iteration   379; current loss is 0.2528311805803831
# Iteration   380; current loss is 0.12509854699973288
# Number of call   330; current loss is 0.12509854699973288
# Iteration   381; current loss is 0.27389566532005327
# Iteration   382; current loss is 0.3358774927765855
# Iteration   383; current loss is 0.13933027645196272
# Number of call   333; current loss is 0.13933027645196272
# Iteration   384; current loss is 0.23818304368920096
# Iteration   385; current loss is 0.19902551289220655
# Iteration   386; current loss is 0.1387650940976555
# Number of call   336; current loss is 0.1387650940976555
# Iteration   387; current loss is 0.2884592009069962
# Iteration   388; current loss is 0.2544999572491774
# Iteration   389; current loss is 0.17082867195216878
# Number of call   339; current loss is 0.17082867195216878
# Iteration   390; current loss is 0.32559294197056143
# Iteration   391; current loss is 0.28395740440174505
# Iteration   392; current loss is 0.12476641538151864
# Iteration   496; current loss is 0.3140965178689526
# Iteration   497; current loss is 0.1381700279589781
# Number of call   447; current loss is 0.1381700279589781
# Iteration   498; current loss is 0.20534048594335852
# Iteration   499; current loss is 0.23051964798675956
# Iteration   500; current loss is 0.12641151926360306
# Number of call   450; current loss is 0.12641151926360306
# Iteration   501; current loss is 0.20298834138106894
# Iteration   502; current loss is 0.17399334629944896
# Iteration   503; current loss is 0.12123790881909594
# Number of call   453; current loss is 0.12123790881909594
# Iteration   504; current loss is 0.4330830641981275
# Iteration   505; current loss is 0.43076292220280277
# Iteration   506; current loss is 0.1304556695525971
# Number of call   456; current loss is 0.1304556695525971
# Iteration   507; current loss is 0.25724942651913413
# Iteration   508; current loss is 0.2611373587354828
# Iteration   509; current loss is 0.12650515163631257
# Number of call   459; current loss is 0.12650515163631257
# Iteration   510; current loss is 0.2068447770221583
# Iteration   511; current loss is 0.2164295421277117
# Iteration   512; current loss is 0.12316995731346175
# Number of call   462; current loss is 0.12316995731346175
# Iteration   513; current loss is 0.32535780138524106
# Iteration   514; current loss is 0.2394145634046121
# Iteration   515; current loss is 0.12213153142896885
# Number of call   465; current loss is 0.12213153142896885
# Iteration   516; current loss is 0.2282148622954514
# Iteration   517; current loss is 0.2164726184641187
# Iteration   518; current loss is 0.10102201038600855
# Number of call   468; current loss is 0.10102201038600855
# Iteration   519; current loss is 0.14886513823713635
# Iteration   520; current loss is 0.27725052619355994
# Iteration   521; current loss is 0.11502590371594087
# Number of call   471; current loss is 0.11502590371594087
# Iteration   522; current loss is 0.1756795108138442
# Iteration   523; current loss is 0.1633851730366191
# Iteration   524; current loss is 0.12217525136002344
# Number of call   474; current loss is 0.12217525136002344
# Iteration   525; current loss is 0.25745199844258826
# Iteration   526; current loss is 0.24422641779624388
# Iteration   527; current loss is 0.12243912250645131
# Number of call   477; current loss is 0.12243912250645131
# Iteration   528; current loss is 0.22491184691310084
# Iteration   529; current loss is 0.2033459771887191
# Iteration   530; current loss is 0.12476293718965269
# Number of call   480; current loss is 0.12476293718965269
# Iteration   531; current loss is 0.3788747816965572
# Iteration   532; current loss is 0.39127131105704704
# Iteration   533; current loss is 0.1108265404987274
# Number of call   483; current loss is 0.1108265404987274
# Iteration   534; current loss is 0.20357880142110002
# Iteration   535; current loss is 0.2866265421765385
# Iteration   536; current loss is 0.11867593250291635
# Number of call   486; current loss is 0.11867593250291635
# Iteration   537; current loss is 0.2142924365207952
# Iteration   538; current loss is 0.24859800655091788
# Iteration   539; current loss is 0.1313214457906069
# Number of call   489; current loss is 0.1313214457906069
# Iteration   540; current loss is 0.2517217719418837
# Iteration   541; current loss is 0.23733926897941285
# Iteration   542; current loss is 0.11407920598339905
# Number of call   492; current loss is 0.11407920598339905
# Iteration   543; current loss is 0.36891805415202483
# Iteration   544; current loss is 0.32154329618987254
# Iteration   545; current loss is 0.09831482451087467
# Number of call   495; current loss is 0.09831482451087467
# Iteration   546; current loss is 0.24871535037461878
# Iteration   650; current loss is 0.11045276582111407
# Number of call   600; current loss is 0.11045276582111407
# Iteration   651; current loss is 0.1884734592006347
# Iteration   652; current loss is 0.216624538656922
# Iteration   653; current loss is 0.09047675758911508
# Number of call   603; current loss is 0.09047675758911508
# Iteration   654; current loss is 0.3367915754414038
# Iteration   655; current loss is 0.37019975889716505
# Iteration   656; current loss is 0.11885692344421314
# Number of call   606; current loss is 0.11885692344421314
# Iteration   657; current loss is 0.3604708889620909
# Iteration   658; current loss is 0.2425317789689314
# Iteration   659; current loss is 0.10242707785656671
# Number of call   609; current loss is 0.10242707785656671
# Iteration   660; current loss is 0.547946098936301
# Iteration   661; current loss is 0.5016098206297672
# Iteration   662; current loss is 0.10674073313209698
# Number of call   612; current loss is 0.10674073313209698
# Iteration   663; current loss is 0.15908992970287236
# Iteration   664; current loss is 0.15922548986191717
# Iteration   665; current loss is 0.15906018652611065
# Number of call   615; current loss is 0.15906018652611065
# Iteration   666; current loss is 0.18729263951462188
# Iteration   667; current loss is 0.21345133010328252
# Iteration   668; current loss is 0.1202015300027799
# Number of call   618; current loss is 0.1202015300027799
# Iteration   669; current loss is 0.23440038880269337
# Iteration   670; current loss is 0.24373875895442032
# Iteration   671; current loss is 0.09554370895898479
# Number of call   621; current loss is 0.09554370895898479
# Iteration   672; current loss is 0.24527895346147666
# Iteration   673; current loss is 0.24732460247650184
# Iteration   674; current loss is 0.11209924053299027
# Number of call   624; current loss is 0.11209924053299027
# Iteration   675; current loss is 0.19201897589532782
# Iteration   676; current loss is 0.14989657009594248
# Iteration   677; current loss is 0.12517360993273519
# Number of call   627; current loss is 0.12517360993273519
# Iteration   678; current loss is 0.19447332688020724
# Iteration   679; current loss is 0.2564856513780285
# Iteration   680; current loss is 0.09450849572314138
# Number of call   630; current loss is 0.09450849572314138
# Iteration   681; current loss is 0.1822815440903053
# Iteration   682; current loss is 0.1989390361224177
# Iteration   683; current loss is 0.10832378304547488
# Number of call   633; current loss is 0.10832378304547488
# Iteration   684; current loss is 0.22777979663464767
# Iteration   685; current loss is 0.19171679009860382
# ...
# Iteration   731; current loss is 0.10382228582960057
# Number of call   681; current loss is 0.10382228582960057
# Iteration   732; current loss is 0.2246444557303104
# Iteration   733; current loss is 0.18650320236393747
# Iteration   734; current loss is 0.11486159502898918
# Number of call   684; current loss is 0.11486159502898918
# Iteration   735; current loss is 0.264973122985022
# Iteration   736; current loss is 0.27139445710757787
# Iteration   737; current loss is 0.10997808434342098
# Number of call   687; current loss is 0.10997808434342098
# Iteration   738; current loss is 0.22797636474311403
# Iteration   739; current loss is 0.20845984496288306
# Iteration   740; current loss is 0.0902417199415321
# Number of call   690; current loss is 0.0902417199415321
# Iteration   741; current loss is 0.27351187876005467
# Iteration   742; current loss is 0.33419148928731346
# Iteration   743; current loss is 0.1084347252081623
# Number of call   693; current loss is 0.1084347252081623
# Iteration   744; current loss is 0.22084340918452677
# Iteration   745; current loss is 0.20211339658248373
# Iteration   746; current loss is 0.12806432731466166
# Number of call   696; current loss is 0.12806432731466166
# Iteration   747; current loss is 0.21978407741804845
# Iteration   748; current loss is 0.18105724899469502
# Iteration   749; current loss is 0.10897768619577594
# Number of call   699; current loss is 0.10897768619577594
# Iteration   750; current loss is 0.1442170930823979
# Iteration   751; current loss is 0.19566423794848004
# Iteration   752; current loss is 0.11713428340913992
# Number of call   702; current loss is 0.11713428340913992
# Iteration   753; current loss is 0.2028723111666945
# Iteration   754; current loss is 0.18169246865324967
# Iteration   755; current loss is 0.10907550459753698
# Number of call   705; current loss is 0.10907550459753698
# Iteration   756; current loss is 0.19849933872132947
# Iteration   757; current loss is 0.17050226112448313
# Iteration   758; current loss is 0.10311285565118428
# Number of call   708; current loss is 0.10311285565118428
# Iteration   759; current loss is 0.24777814510809593
# Iteration   760; current loss is 0.25228482140549335
# Iteration   761; current loss is 0.12812285741539703
# Number of call   711; current loss is 0.12812285741539703
# Iteration   762; current loss is 0.2413611974351643
# Iteration   763; current loss is 0.20527274016182617
# Iteration   764; current loss is 0.10321258483303021
# Number of call   714; current loss is 0.10321258483303021
# Iteration   765; current loss is 0.2344085863053496
# Iteration   766; current loss is 0.25825578587625053
# Iteration   767; current loss is 0.09840095148083951
# Number of call   717; current loss is 0.09840095148083951
# Iteration   768; current loss is 0.22226894972296804
# Iteration   769; current loss is 0.22426663256379664
# Iteration   770; current loss is 0.11613270731249954
# Number of call   720; current loss is 0.11613270731249954
# Iteration   771; current loss is 0.2571324494045521
# Iteration   772; current loss is 0.26243161276750926
# Iteration   773; current loss is 0.10714114976125119
# Number of call   723; current loss is 0.10714114976125119
# Iteration   774; current loss is 0.2522240253092377
# Iteration   775; current loss is 0.23352046569889187
# Iteration   776; current loss is 0.1117554998845085
# Number of call   726; current loss is 0.1117554998845085
# Iteration   777; current loss is 0.13638660468727326
# Iteration   778; current loss is 0.18058900295080899
# Iteration   779; current loss is 0.09901651116608831
# Number of call   729; current loss is 0.09901651116608831
# Iteration   780; current loss is 0.33569010239219454
# Iteration   781; current loss is 0.3922454114216293
# Iteration   782; current loss is 0.11048486826747142
# Number of call   732; current loss is 0.11048486826747142
# Iteration   783; current loss is 0.1618177192034937
# Iteration   784; current loss is 0.11969634664509235
# Iteration   785; current loss is 0.09705944890851526
# Number of call   735; current loss is 0.09705944890851526
# Iteration   786; current loss is 0.25477233846961755
# Iteration   787; current loss is 0.23322343686325978
# Iteration   788; current loss is 0.11727088769762661
# Number of call   738; current loss is 0.11727088769762661
# Iteration   789; current loss is 0.22251857813590142
# Iteration   790; current loss is 0.18588282615691948
# Iteration   791; current loss is 0.10266678516949443
# Number of call   741; current loss is 0.10266678516949443
# Iteration   792; current loss is 0.3917217898045202
# Iteration   793; current loss is 0.3344330777345287
# Iteration   794; current loss is 0.10653437774599452
# Number of call   744; current loss is 0.10653437774599452
# Iteration   795; current loss is 0.39156870356490353
# Iteration   796; current loss is 0.4231840616625268
# Iteration   797; current loss is 0.11372820748937812
# Number of call   747; current loss is 0.11372820748937812
# Iteration   798; current loss is 0.228385486307275
# Iteration   799; current loss is 0.28343292857047686
# Iteration   800; current loss is 0.13446979867873451
# Number of call   750; current loss is 0.13446979867873451
# Iteration   801; current loss is 0.20014265711666032
# Iteration   802; current loss is 0.18861296416677772
# Iteration   803; current loss is 0.11959238716255269
# Number of call   753; current loss is 0.11959238716255269
# Iteration   804; current loss is 0.1946630518480606
# Iteration   805; current loss is 0.2635196916022969
# Iteration   806; current loss is 0.11469722666525428
# Number of call   756; current loss is 0.11469722666525428
# Iteration   807; current loss is 0.20756178248305904
# Iteration   808; current loss is 0.15573979732675755
# Iteration   809; current loss is 0.10456678072020853
# Number of call   759; current loss is 0.10456678072020853
# Iteration   810; current loss is 0.17168161233474
# Iteration   811; current loss is 0.18704587165130482
# Iteration   812; current loss is 0.0854984101886823
# Number of call   762; current loss is 0.0854984101886823
# Iteration   813; current loss is 0.2586254113381874
# Iteration   814; current loss is 0.22218965964860166
# Iteration   815; current loss is 0.11644302102630943
# Number of call   765; current loss is 0.11644302102630943
# Iteration   816; current loss is 0.19373955768875475
# Iteration   817; current loss is 0.17834933111629966
# Iteration   818; current loss is 0.11098485491507107
# Number of call   768; current loss is 0.11098485491507107
# Iteration   819; current loss is 0.23851294783593968
# Iteration   820; current loss is 0.2893155735150379
# Iteration   821; current loss is 0.11424331598565442
# Number of call   771; current loss is 0.11424331598565442
# Iteration   822; current loss is 0.28661024651431694
# Iteration   823; current loss is 0.2573453018584693
# Iteration   824; current loss is 0.09864697470112323
# Number of call   774; current loss is 0.09864697470112323
# Iteration   825; current loss is 0.21368922247942954
# Iteration   826; current loss is 0.18593636782496384
# Iteration   827; current loss is 0.10702532650631935
# Number of call   777; current loss is 0.10702532650631935
# Iteration   828; current loss is 0.2421964843738525
# Iteration   829; current loss is 0.27323429027988455
# Iteration   830; current loss is 0.0968125961689098
# Number of call   780; current loss is 0.0968125961689098
# Iteration   831; current loss is 0.16525049637422373
# Iteration   832; current loss is 0.18568692270163836
# Iteration   833; current loss is 0.11192482276575295
# Number of call   783; current loss is 0.11192482276575295
# Iteration   834; current loss is 0.22661179822811117
# Iteration   835; current loss is 0.25774552255143235
# Iteration   836; current loss is 0.09414379984728044
# Number of call   786; current loss is 0.09414379984728044
# Iteration   837; current loss is 0.24931188564418577
# Iteration   838; current loss is 0.23793039816814532
# Iteration   839; current loss is 0.11784061609468463
# Number of call   789; current loss is 0.11784061609468463
# Iteration   840; current loss is 0.1317568265213948
# Iteration   841; current loss is 0.17249272960627338
# Iteration   842; current loss is 0.11764740187205304
# Number of call   792; current loss is 0.11764740187205304
# Iteration   843; current loss is 0.3506766037041734
# Iteration   844; current loss is 0.3747943968276688
# Iteration   845; current loss is 0.09621606089365353
# Number of call   795; current loss is 0.09621606089365353
# Iteration   846; current loss is 0.1898982993215807
# Iteration   847; current loss is 0.1930345838478773
# Iteration   848; current loss is 0.10829253714151682
# Number of call   798; current loss is 0.10829253714151682
# Iteration   849; current loss is 0.18634149114507842
# Iteration   850; current loss is 0.18464669242124715
# Iteration   851; current loss is 0.12638958594402067
# Number of call   801; current loss is 0.12638958594402067
# Iteration   852; current loss is 0.2555448687228991
# Iteration   853; current loss is 0.2812947656119801
# Iteration   854; current loss is 0.11712137736190179
# Number of call   804; current loss is 0.11712137736190179
# Iteration   855; current loss is 0.15899092412709695
# Iteration   856; current loss is 0.18373263020511152
# Iteration   857; current loss is 0.11002478836891376
# Number of call   807; current loss is 0.11002478836891376
# Iteration   858; current loss is 0.25585369924546747
# Iteration   859; current loss is 0.2419172252120067
# Iteration   860; current loss is 0.10207434335225557
# Number of call   810; current loss is 0.10207434335225557
# Iteration   861; current loss is 0.21380160188413114
# Iteration   862; current loss is 0.2506091685774121
# Iteration   863; current loss is 0.1408974973291658
# Number of call   813; current loss is 0.1408974973291658
# Iteration   864; current loss is 0.22611736983032543
# Iteration   865; current loss is 0.22256862248457943
# Iteration   866; current loss is 0.0932744682573944
# Number of call   816; current loss is 0.0932744682573944
# Iteration   867; current loss is 0.19888815040844848
# Iteration   868; current loss is 0.23840069717519885
# Iteration   869; current loss is 0.0958599232391022
# Number of call   819; current loss is 0.0958599232391022
# Iteration   870; current loss is 0.3077596743935569
# Iteration   871; current loss is 0.2697109728281265
# Iteration   872; current loss is 0.10797736554472684
# Number of call   822; current loss is 0.10797736554472684
# Iteration   873; current loss is 0.22683855339944398
# Iteration   874; current loss is 0.18009349679403297
# Iteration   875; current loss is 0.10527902209379192
# Number of call   825; current loss is 0.10527902209379192
# Iteration   876; current loss is 0.26381663667549066
# Iteration   877; current loss is 0.3681733146986627
# Iteration   878; current loss is 0.09304373912448627
# Number of call   828; current loss is 0.09304373912448627
# Iteration   879; current loss is 0.23909878022641787
# Iteration   880; current loss is 0.20878215751293344
# Iteration   881; current loss is 0.10069861634199974
# Number of call   831; current loss is 0.10069861634199974
# Iteration   882; current loss is 0.2481285756906464
# Iteration   883; current loss is 0.2820922235335429
# Iteration   884; current loss is 0.09933996493401703
# Number of call   834; current loss is 0.09933996493401703
# Iteration   885; current loss is 0.21563509119075558
# Iteration   886; current loss is 0.210033817429913
# Iteration   887; current loss is 0.08317656087489586
# Number of call   837; current loss is 0.08317656087489586
# Iteration   888; current loss is 0.15363053944605468
# Iteration   889; current loss is 0.22731092917290388
# Iteration   890; current loss is 0.11837928179876384
# Number of call   840; current loss is 0.11837928179876384
# Iteration   891; current loss is 0.16519702327030347
# Iteration   892; current loss is 0.2071280915219528
# Iteration   893; current loss is 0.11289370242059846
# Number of call   843; current loss is 0.11289370242059846
# Iteration   894; current loss is 0.250048328483352
# Iteration   895; current loss is 0.3011350605134864
# Iteration   896; current loss is 0.1196324579603199
# Number of call   846; current loss is 0.1196324579603199
# Iteration   897; current loss is 0.14833086946554613
# Iteration   898; current loss is 0.14336396121648975
# Iteration   899; current loss is 0.10205860065260755
# Number of call   849; current loss is 0.10205860065260755
# Iteration   900; current loss is 0.3330005477199376
# Iteration   901; current loss is 0.3382949994660861
# Iteration   902; current loss is 0.0834069567021735
# Number of call   852; current loss is 0.0834069567021735
# Iteration   903; current loss is 0.25638816790171454
# Iteration   904; current loss is 0.3127839363254061
# Iteration   905; current loss is 0.1118121164152456
# Number of call   855; current loss is 0.1118121164152456
# Iteration   906; current loss is 0.20390274617957913
# Iteration   907; current loss is 0.20256955749374467
# Iteration   908; current loss is 0.1016082999757867
# Number of call   858; current loss is 0.1016082999757867
# Iteration   909; current loss is 0.15003593357808354
# Iteration   910; current loss is 0.14751913496089675
# Iteration   911; current loss is 0.09651732450477546
# Number of call   861; current loss is 0.09651732450477546
# Iteration   912; current loss is 0.23403104256296825
# Iteration   913; current loss is 0.28013055200064496
# Iteration   914; current loss is 0.10608932178696123
# Number of call   864; current loss is 0.10608932178696123
# Iteration   915; current loss is 0.17199374919348748
# Iteration   916; current loss is 0.12256410399520304
# Iteration   917; current loss is 0.11441343453619264
# Number of call   867; current loss is 0.11441343453619264
# Iteration   918; current loss is 0.30348063723421964
# Iteration   919; current loss is 0.3037377295209117
# Iteration   920; current loss is 0.13436953811136432
# Number of call   870; current loss is 0.13436953811136432
# Iteration   921; current loss is 0.13876790465000907
# Iteration   922; current loss is 0.15446441782417383
# Iteration   923; current loss is 0.0920004824071
# Number of call   873; current loss is 0.0920004824071
# Iteration   924; current loss is 0.19973730044368002
# Iteration   925; current loss is 0.21614720087504552
# Iteration   926; current loss is 0.11167685435693823
# Number of call   876; current loss is 0.11167685435693823
# Iteration   927; current loss is 0.28916577202676946
# Iteration   928; current loss is 0.2556007082504722
# Iteration   929; current loss is 0.12279724278254611
# Number of call   879; current loss is 0.12279724278254611
# Iteration   930; current loss is 0.27845309144729213
# Iteration   931; current loss is 0.3056887303741237
# Iteration   932; current loss is 0.125678803109718
# Number of call   882; current loss is 0.125678803109718
# Iteration   933; current loss is 0.28397080586081974
# Iteration   934; current loss is 0.2518472832099172
# Iteration   935; current loss is 0.1055551997380936
# Number of call   885; current loss is 0.1055551997380936
# Iteration   936; current loss is 0.28170649220546684
# Iteration   937; current loss is 0.24503795002893614
# Iteration   938; current loss is 0.0900141473286296
# Number of call   888; current loss is 0.0900141473286296
# Iteration   939; current loss is 0.19667663794509216
# Iteration   940; current loss is 0.18006834656655812
# Iteration   941; current loss is 0.10885725701940532
# Number of call   891; current loss is 0.10885725701940532
# Iteration   942; current loss is 0.1753792769022333
# Iteration   943; current loss is 0.19860808739213223
# Iteration   944; current loss is 0.10440566709307765
# Number of call   894; current loss is 0.10440566709307765
# Iteration   945; current loss is 0.21566201622021602
# Iteration   946; current loss is 0.2532481210722575
# Iteration   947; current loss is 0.10256767548799625
# Number of call   897; current loss is 0.10256767548799625
# Iteration   948; current loss is 0.2588846022130803
# Iteration   949; current loss is 0.2706988796959007
# Iteration   950; current loss is 0.09356008138271442
# Number of call   900; current loss is 0.09356008138271442
# Iteration   951; current loss is 0.09511520876904284
# CPU times: user 2min 57s, sys: 11min 22s, total: 14min 19s
# Wall time: 54.5 s

# %%
fig, ax = plt.subplots()
ax.plot(loss_values, label=f"KL Loss")
# plt.ylim(0, 30)
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.set_title(f"Loss Function over Iterations - Alternating Ansatz + KL divergence")
ax.legend()

# fig.savefig("loss_curve.png")

# %%
def simulate_circ(circ):
    """
    Generates our estimate state |phi> via simulation
    :param circ: qiskit.QuantumCircuit object, the variational quantum circuit
    :return: qiskit.Statevector object, represents our estimated quantum state |phi>
    """

    simulator = AerSimulator(method='statevector')
    circ.save_statevector() 
    job = simulator.run(circ)
    result = job.result()
    circ_statevect = Statevector(result.get_statevector(circ))
    
    return circ_statevect

def compute_fidelity(psi, phi):
    """
    Compute the fidelity (a measure of similarity) between the two states
    :param psi: qiskit.Statevector, our target state |psi>
    :param phi: qiskit.Statevector, our estimated state |phi>
    :return: float, fidelity
    """

    fidelity = qiskit.quantum_info.state_fidelity(psi, phi)
    print(f"psi: {psi}, phi: {phi}")
    # fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    # plot_bloch_multivector(psi)
    # axes[0].set_title("psi")
    # plot_bloch_multivector(phi)
    # axes[1].set_title("phi")
    return fidelity



ghz_state = Statevector.from_instruction(ghz_circ)
ansatz_state = Statevector.from_instruction(ansatz.assign_parameters({param_vec : results.x}))

final_fidelity = qiskit.quantum_info.state_fidelity(ghz_state, ansatz_state)

# %%
print(f"ghz state: {ghz_state}\nansatz: {ansatz_state}")
# Out:
# ghz state: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.70710678+0.j],
#             dims=(2, 2, 2))
# ansatz: Statevector([ 0.69454349-0.03536791j, -0.00566265+0.00637424j,
#              -0.01277654-0.01392171j,  0.00360344+0.00012616j,
#               0.03312984+0.00647996j, -0.00864013+0.00919569j,
#               0.0312694 -0.0168094j ,  0.70897284-0.10350887j],
#             dims=(2, 2, 2))

# %%
print(final_fidelity)
# Out:
# 0.9945724303797524

# %%
print(results.x)
# Out:
# [ 0.08169828  1.62191658 -1.00611657 -1.74018369  1.30939587  1.04730537
#   1.26742454 -1.42297958  1.89872465  0.84458638  0.00913317 -1.42508427
#   1.92414823  1.9879731   0.36415578  0.07746575 -1.13508556 -0.17796733
#   0.04917987  0.72909344  1.69905098  1.5137778   1.88047128  1.58059981
#   0.87643359 -1.37454854 -1.55499183  0.27500276 -0.05184308  0.25214917]

# %%
np.save(f"saved/params_training_s{trial}.npy", thetas)
np.save(f"saved/loss_training_s{trial}.npy", loss_values)
np.save(f"saved/loss_training_proper_s{trial}.npy", loss_proper_values)
np.save(f"saved/final_theta_s{trial}.npy", results.x)
np.save(f"saved/fidelity_s{trial}.npy", final_fidelity)

# %%
from qiskit.visualization import plot_state_city

# %%
plot_state_city(ghz_state, title=None)

# %%
plot_state_city(ansatz_state, title=None)
