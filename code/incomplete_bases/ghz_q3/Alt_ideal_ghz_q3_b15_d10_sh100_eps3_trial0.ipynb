# %%
import os
from math import pi
import numpy as np
import random
import itertools
import scipy.optimize as opt
import matplotlib.pyplot as plt
import qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_state_city
# from qiskit_aer.noise import NoiseModel
# from qiskit_ibm_provider import IBMProvider
from qiskit_algorithms.optimizers import SPSA

# %%
shots = 100
epsilon_loss = 1e-3 # loss added if test_counts entry is not found
epsilon_parameters=0.1 # scaling factor for initial random parameters (chosen between 0 to 2pi otherwise)

n_qubits = 3
n_bases = 15
depth = 10

max_iter = 1000

param_name = "theta"

# save checkpoints in case the connection to qpu breaks
# useful for running on real qpu, but not necessary for local simulation
have_checkpoints = False
checkpoint_path = "Alt_ideal_ghz_q3_b27_d6_sh100_checkpoints"

# seed = 1000
trial = 0

# %%
# random.seed(seed)
rng = np.random.default_rng()

# %%
# if have_checkpoints:
#     os.mkdir(checkpoint_path)

# %%
# backend = AerSimulator()
# sampler = Sampler.from_backend(backend)
# pm = generate_preset_pass_manager(backend=backend)

simulator_ideal = AerSimulator()
# simulator_ideal.set_options(seed_simulator=seed)
# sampler_ideal = Sampler.from_backend(simulator_ideal)
pm_ideal = generate_preset_pass_manager(backend=simulator_ideal, optimization_level=1)

# sampler = sampler_ideal
pm = pm_ideal

# %%
def create_ghz_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n - 1):
        qc.cx(i, i + 1)
    return qc

def get_circ_for_basis(qc: QuantumCircuit, basis: str):
    circ = qc.copy()
    for i, s in enumerate(basis[::-1]): # here, I am using the same endian convention as qiskit, where the last bit represent the first qubit
        if s == 'Z':
            pass
        elif s == 'X':
            circ.ry(-pi/2, i)
        elif s == 'Y':
            circ.rx(pi/2, i)
        else:
            raise ValueError(f"{s} is invalid basis")

    circ.measure_all()

    return circ

def get_isa_circ_list_for_bases(qc: QuantumCircuit, basis_list, pass_manager):
    circ_list = [get_circ_for_basis(qc, basis) for basis in basis_list]
    isa_circ_list = pass_manager.run(circ_list)
    return isa_circ_list


def measure_isa_circ_list_fs(isa_circ_list, basis_list, shots=shots):
    sampler = Sampler(seed =rng.integers(1000000) )
    result_list = sampler.run(isa_circ_list, shots=shots).result()
    counts_list = [result.data.meas.get_counts() for result in result_list]
    results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    return results_dic


def get_basis_list(n_bases,n_qubits):
    bases = ["X", "Y", "Z"]
    basis_list = ["".join(p) for p in itertools.product(bases, repeat=n_qubits)]
    culled_basis_list = random.sample(basis_list, n_bases)
    return culled_basis_list




# def measure_circ_for_all_basis(qc, basis_list, shots=total_shots, sampler=None):
#     results_dic = {}
#     qc_list = [get_circ_for_basis(qc, basis, simulator) for basis in basis_list]
#     job = simulator.run(qc_list, shots=shots)
#     result = job.result()
#     counts_list = result.get_counts()
#     results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    
#     return results_dic

# %%
basis_list = get_basis_list(n_bases, n_qubits)
ghz_circ = create_ghz_state(n_qubits)
ghz_circ_isa_list = get_isa_circ_list_for_bases(ghz_circ, basis_list, pm_ideal)
GHZ_measurement = measure_isa_circ_list_fs(ghz_circ_isa_list, basis_list, shots=shots)

# %%
print(basis_list)
# Out:
# ['ZZY', 'XZX', 'YXZ', 'ZZZ', 'XXY', 'XYY', 'ZZX', 'YXY', 'ZXZ', 'YYZ', 'XYZ', 'YYY', 'YZY', 'YXX', 'XXX']

# %%
print(GHZ_measurement)
# Out:
# {'ZZY': {'001': 28, '110': 26, '000': 29, '111': 17}, 'XZX': {'010': 8, '001': 19, '011': 15, '111': 5, '101': 12, '100': 9, '110': 15, '000': 17}, 'YXZ': {'011': 12, '010': 15, '110': 16, '100': 11, '001': 11, '111': 12, '000': 13, '101': 10}, 'ZZZ': {'000': 48, '111': 52}, 'XXY': {'010': 13, '110': 14, '111': 13, '000': 13, '100': 9, '011': 12, '101': 13, '001': 13}, 'XYY': {'100': 32, '010': 19, '111': 32, '001': 17}, 'ZZX': {'000': 26, '111': 24, '110': 28, '001': 22}, 'YXY': {'100': 20, '001': 23, '010': 22, '111': 35}, 'ZXZ': {'010': 30, '111': 25, '101': 23, '000': 22}, 'YYZ': {'111': 11, '100': 14, '000': 14, '101': 18, '110': 10, '001': 16, '011': 6, '010': 11}, 'XYZ': {'001': 12, '000': 13, '110': 18, '010': 16, '111': 11, '011': 11, '101': 11, '100': 8}, 'YYY': {'001': 13, '100': 14, '110': 13, '011': 12, '000': 12, '101': 13, '111': 16, '010': 7}, 'YZY': {'010': 18, '011': 15, '101': 10, '100': 8, '000': 17, '001': 13, '110': 10, '111': 9}, 'YXX': {'101': 14, '111': 18, '110': 11, '001': 10, '010': 8, '100': 11, '011': 13, '000': 15}, 'XXX': {'011': 29, '000': 24, '101': 19, '110': 28}}

# %%
def initialize_theta_random(circ_depth=10, num_qbits=3):
    """
    Initialize the theta parameter vector
    :param circ_depth: int, number of parameterized layers in circuit
    :param num_qbits: int, number of qbits
    :return: np.array, values of theta
    """

    theta = rng.random(size=(circ_depth, num_qbits))
    theta = 2*pi*epsilon_parameters*theta
    return theta

# %%
def construct_variational_circ_ansatz(num_qbits, circ_depth, param_name = param_name):
    """
    Generate a parameterized variational quantum circuit
    
    """

    num_parameters = num_qbits * circ_depth
    theta_vec = ParameterVector(param_name, length=num_parameters)
    var_circ = QuantumCircuit(num_qbits)


    for layer in range(circ_depth - 1):
        # Compute if layer is odd or even to apply rx or ry gate to circuit
        is_odd_step = (layer + 1) % 2

        for qbit in range(num_qbits):
            if is_odd_step:
                var_circ.rx(theta_vec[layer * num_qbits + qbit], qbit)
            else:
                var_circ.ry(theta_vec[layer * num_qbits + qbit], qbit)

        # Apply CX gates
        for qbit in range((1-is_odd_step), num_qbits-1, 2):
            # isOddStep may subtract 1 if True, to correctly apply cx gate location
            var_circ.cx(qbit , qbit + 1)
            var_circ.barrier() # for visualization only

    for qbit in range(num_qbits):  # bonus layer at the end only has rx gates and no cx
        var_circ.rx(theta_vec[(circ_depth - 1) * num_qbits + qbit], qbit)

    return var_circ, theta_vec

# %%
ansatz, param_vec = construct_variational_circ_ansatz(n_qubits, depth, param_name=param_name)

# %%
ansatz.draw(output="mpl", style="clifford")

# %%
ansatz_isa_list = get_isa_circ_list_for_bases(ansatz, basis_list, pm)

# %%
def get_ansatz_output(ansatz_isa_list, parameters, basis_list, shots, param_placeholder=param_vec):
    circ_run_list = [circ.assign_parameters({param_placeholder:parameters}) for circ in ansatz_isa_list]
    return measure_isa_circ_list_fs(isa_circ_list=circ_run_list, basis_list=basis_list, shots=shots)

# %%
def KL_divergence(true_data, test_data, epsilon_loss = epsilon_loss):
    loss = 0

    # here, let me assume true data and test data can have different number of shots
    # but the shot in each basis should be the same
    true_data_total_shots = sum(list(true_data.values())[0].values())
    test_data_total_shots = sum(list(test_data.values())[0].values())

    for basis in true_data: # just a note that if there are hallucinated measurements in 
        # bases/states not included in the true data then the kl divergence will not account for these (at least as presented in the paper)
        for state in true_data[basis]:
            true_counts = true_data[basis][state]
            test_counts = test_data[basis].get(state, 0)
            true_prob   = true_counts / true_data_total_shots
            test_prob   = test_counts / test_data_total_shots
            loss += true_prob *(np.log((true_prob)/(test_prob +epsilon_loss)))

    return loss / len(true_data)

# %%
global loss_values
global thetas

loss_values = []
thetas = []

# %%
def compute_kl_loss(theta_vector, ansatz_isa_list,  basis_list, true_data, shots, param_placeholder=param_vec, \
        print_message=True, have_checkpoints=have_checkpoints, checkpoint_path=checkpoint_path):
    # theta = np.reshape(theta_vector, (circ_depth, num_qbits))
    # tempcirc = construct_variational_circ(theta=theta)
    test_data = get_ansatz_output(ansatz_isa_list=ansatz_isa_list, parameters=theta_vector, basis_list=basis_list, \
        shots=shots, param_placeholder=param_placeholder)
    # test_data = measure_circ_for_all_basis(qc = tempcirc, basis_list=basis_list, simulator=simulator)
    loss = KL_divergence(true_data, test_data) + \
        KL_divergence(test_data, true_data) # symmetrizing the loss

    global loss_values
    global thetas 
    loss_values.append(loss)
    thetas.append(theta_vector)

    num_iter = len(loss_values)

    if print_message:
        print(f"Iteration {num_iter:5}; current loss is {loss}")

    if have_checkpoints:
        # save checkpoints in case the connection to qpu breaks
        # useful for running on real qpu, but not necessary for local simulation
        np.save(os.path.join(checkpoint_path, f"theta_iter{num_iter}.npy"), thetas)
    
    return loss

# %%
# wraps the function with the all arguments but theta vector already filled

def compute_kl_loss_filled(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec, print_message=True)

def compute_kl_loss_filled_quiet(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec, print_message=False)

# %%
# %%time

theta = initialize_theta_random(circ_depth=depth, num_qbits = n_qubits)
theta_vector = np.reshape(theta, theta.size)
circ_depth, num_qbits = theta.shape

spsa = SPSA(maxiter=300)
# c=0.1258
# A=0.3186
# a1=0.4739
# alpha=0.6374
# gamma=0.06059
# (lr, p) = spsa.calibrate(compute_kl_loss_filled, theta_vector, c=c, stability_constant = A, target_magnitude=a1, alpha=alpha, gamma=gamma)
# spsa.learning_rate = lr
# spsa.perturbation = p

# args = (ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec)

# results = opt.minimize(compute_kl_loss, theta_vector, args = args, method = "Powell", options={"maxiter":max_iter})

results = spsa.minimize(compute_kl_loss_filled, theta_vector)
# Out:
# Iteration     1; current loss is 2.9102801210518408
# Iteration     2; current loss is 3.0652987811227357
# Iteration     3; current loss is 3.2104785142899406
# Iteration     4; current loss is 2.7518984091856566
# Iteration     5; current loss is 2.974512632589708
# Iteration     6; current loss is 2.516813261060678
# Iteration     7; current loss is 2.9908148430620827
# Iteration     8; current loss is 2.7105595145587125
# Iteration     9; current loss is 2.849373986291565
# Iteration    10; current loss is 2.8016158081563836
# Iteration    11; current loss is 2.800125560985959
# Iteration    12; current loss is 2.536680277009432
# Iteration    13; current loss is 3.0166234931501457
# Iteration    14; current loss is 2.8156546601686276
# Iteration    15; current loss is 2.4136622605772615
# Iteration    16; current loss is 2.596676765684112
# Iteration    17; current loss is 2.8306816660357406
# Iteration    18; current loss is 2.4346278250250597
# Iteration    19; current loss is 3.1100977916141526
# Iteration    20; current loss is 2.9571756129559965
# Iteration    21; current loss is 2.6598563884994286
# Iteration    22; current loss is 2.660954171774058
# Iteration    23; current loss is 3.0032823756765747
# Iteration    24; current loss is 2.7680991465745506
# Iteration    25; current loss is 2.4529913956606237
# Iteration    26; current loss is 2.26910575793159
# Iteration    27; current loss is 2.6560106005345387
# Iteration    28; current loss is 3.1785000080203396
# Iteration    29; current loss is 2.630541726286446
# Iteration    30; current loss is 3.0748784338087134
# Iteration    31; current loss is 3.1440314882006706
# Iteration    32; current loss is 2.6999250887926878
# Iteration    33; current loss is 2.493731581262397
# Iteration    34; current loss is 2.7330051114080836
# Iteration    35; current loss is 2.7718011637407662
# Iteration    36; current loss is 3.136269227988363
# Iteration    37; current loss is 2.6027356192178965
# Iteration    38; current loss is 2.705895279517936
# Iteration    39; current loss is 2.641615433516561
# Iteration    40; current loss is 2.9042453783345863
# Iteration    41; current loss is 2.3299562385720725
# Iteration    42; current loss is 3.0653498229129337
# Iteration    43; current loss is 2.6462153143028697
# Iteration    44; current loss is 3.2531809461564842
# Iteration    45; current loss is 2.9187914069906093
# Iteration    46; current loss is 2.7094785407914035
# Iteration    47; current loss is 2.76129674741979
# Iteration    48; current loss is 2.6370253773579146
# Iteration    49; current loss is 2.8435562066969426
# Iteration    50; current loss is 2.8247973782632108
# Iteration    51; current loss is 2.557852628149403
# Iteration    52; current loss is 3.1367803331871205
# Iteration    53; current loss is 2.5054370036598366
# Iteration    54; current loss is 2.439212664671724
# Iteration    55; current loss is 2.6531376550132384
# Iteration    56; current loss is 2.7687327782840008
# Iteration    57; current loss is 2.789165890763261
# Iteration    58; current loss is 2.534669508406958
# Iteration    59; current loss is 2.733290904431059
# Iteration    60; current loss is 2.342644728442621
# Iteration    61; current loss is 2.032526227882882
# Iteration    62; current loss is 1.912101766206381
# Iteration    63; current loss is 1.9713123729909867
# Iteration    64; current loss is 2.1585917626925024
# Iteration    65; current loss is 2.340014595348026
# Iteration    66; current loss is 2.024670625319863
# Iteration    67; current loss is 1.8353397467000474
# Iteration    68; current loss is 2.631268062282883
# Iteration    69; current loss is 1.332349866256961
# Iteration    70; current loss is 2.932379350457259
# Iteration    71; current loss is 2.927245480174542
# Iteration    72; current loss is 2.1444030463351234
# Iteration    73; current loss is 2.297327327636777
# Iteration    74; current loss is 1.845130714023505
# Iteration    75; current loss is 2.16909032398896
# Iteration    76; current loss is 2.0308958567095265
# Iteration    77; current loss is 1.963318144694184
# Iteration    78; current loss is 2.091563104191383
# Iteration    79; current loss is 1.9833595552324468
# Iteration    80; current loss is 1.8128824651786455
# Iteration    81; current loss is 2.0787776963476077
# Iteration    82; current loss is 2.234870071257389
# Iteration    83; current loss is 2.015073047329252
# Iteration    84; current loss is 2.1712310470997225
# Iteration    85; current loss is 2.052226342718821
# Iteration    86; current loss is 1.7943852384365093
# Iteration    87; current loss is 1.7881821852028705
# Iteration    88; current loss is 2.0867225470563504
# Iteration    89; current loss is 2.281055359302934
# Iteration    90; current loss is 1.5899491698215846
# Iteration    91; current loss is 2.4106501001553866
# Iteration    92; current loss is 1.7795583586950094
# Iteration    93; current loss is 1.96094339749237
# Iteration    94; current loss is 2.0674934666795144
# Iteration    95; current loss is 2.2880584244994475
# Iteration    96; current loss is 1.5901819826545607
# Iteration    97; current loss is 1.5118376229525783
# Iteration    98; current loss is 2.016639864541877
# Iteration    99; current loss is 1.8925325501245653
# Iteration   100; current loss is 2.1555433956316983
# Iteration   101; current loss is 2.154487735047502
# Iteration   102; current loss is 1.9781621238401652
# Iteration   103; current loss is 1.8696988774959795
# Iteration   104; current loss is 1.9267336546488276
# Iteration   105; current loss is 2.1919837053378655
# Iteration   106; current loss is 1.698642081578849
# Iteration   107; current loss is 1.961371798751653
# Iteration   108; current loss is 1.8057625763948135
# Iteration   109; current loss is 1.6341672276250754
# Iteration   110; current loss is 2.0253522250901774
# Iteration   111; current loss is 1.5521328437848878
# Iteration   112; current loss is 1.8071600572092192
# Iteration   113; current loss is 1.6055801523765907
# Iteration   114; current loss is 1.894297015519487
# Iteration   115; current loss is 2.042790798554328
# Iteration   116; current loss is 1.510379720038188
# Iteration   117; current loss is 1.3475875480507757
# Iteration   118; current loss is 2.547095488107561
# Iteration   119; current loss is 2.423592406305964
# Iteration   120; current loss is 1.4802699824057401
# Iteration   121; current loss is 2.531473774093487
# Iteration   122; current loss is 2.5984204312846373
# Iteration   123; current loss is 2.216295048472767
# Iteration   124; current loss is 2.301017481105021
# Iteration   125; current loss is 2.237684853490035
# Iteration   126; current loss is 2.473831489239422
# Iteration   127; current loss is 2.4466602230967123
# Iteration   128; current loss is 1.5554701808040752
# Iteration   129; current loss is 1.4948966737382905
# Iteration   130; current loss is 1.8951881233566041
# Iteration   131; current loss is 1.6244109418402222
# Iteration   132; current loss is 1.6033439305932988
# Iteration   133; current loss is 1.615354182973062
# Iteration   134; current loss is 1.5557822204046818
# Iteration   135; current loss is 1.7231114724841432
# Iteration   136; current loss is 1.858271746751074
# Iteration   137; current loss is 1.7918005897261904
# Iteration   138; current loss is 1.3909296823225497
# Iteration   139; current loss is 1.786048079135794
# Iteration   140; current loss is 2.0283816639328136
# Iteration   141; current loss is 1.6833783322421354
# Iteration   142; current loss is 1.801634059789786
# Iteration   143; current loss is 1.7376523112895852
# Iteration   144; current loss is 1.5103333434625754
# Iteration   145; current loss is 1.4341009313814101
# Iteration   146; current loss is 1.9583845714466972
# Iteration   147; current loss is 2.0106583817032355
# Iteration   148; current loss is 1.4198594642870699
# Iteration   149; current loss is 1.6908477111729812
# Iteration   150; current loss is 1.710676871922074
# Iteration   151; current loss is 1.7649056460941193
# Iteration   152; current loss is 1.2244191636104302
# Iteration   153; current loss is 1.8017882862449417
# Iteration   154; current loss is 0.9299869367120115
# Iteration   155; current loss is 1.2283103675154647
# Iteration   156; current loss is 1.425528982634769
# Iteration   157; current loss is 1.9683604751118458
# Iteration   158; current loss is 0.5927542473048915
# Iteration   159; current loss is 1.2811486282875522
# Iteration   160; current loss is 1.5021092575773463
# Iteration   161; current loss is 1.0069229069485366
# Iteration   162; current loss is 2.0225968586833853
# Iteration   163; current loss is 1.6096794136097214
# Iteration   164; current loss is 1.8401558255249333
# Iteration   165; current loss is 1.344584443850104
# Iteration   166; current loss is 1.7509190502039393
# Iteration   167; current loss is 1.4367396238494414
# Iteration   168; current loss is 1.3049864704286858
# Iteration   169; current loss is 1.609814864552228
# Iteration   170; current loss is 1.4313496437447346
# Iteration   171; current loss is 1.312623246392254
# Iteration   172; current loss is 1.5033427665514
# Iteration   173; current loss is 1.7221155664876169
# Iteration   174; current loss is 1.4916313433720199
# Iteration   175; current loss is 1.4137830689997284
# Iteration   176; current loss is 1.947327834754806
# Iteration   177; current loss is 1.3881613015853547
# Iteration   178; current loss is 1.7091089490757585
# Iteration   179; current loss is 1.3770421991920774
# Iteration   180; current loss is 1.8517871530993473
# Iteration   181; current loss is 1.7954705337131804
# Iteration   182; current loss is 1.3842227820926623
# Iteration   183; current loss is 1.4779938568730455
# Iteration   184; current loss is 1.7020589604654215
# Iteration   185; current loss is 1.1630424264281036
# Iteration   186; current loss is 1.583768389302382
# Iteration   187; current loss is 1.2403339586316497
# Iteration   188; current loss is 1.5595745730072776
# Iteration   189; current loss is 0.894915560839741
# Iteration   190; current loss is 1.7367037619886587
# Iteration   191; current loss is 0.9028636121063245
# Iteration   192; current loss is 1.2313948272436497
# Iteration   193; current loss is 0.9271299245467198
# Iteration   194; current loss is 1.2140138503218572
# Iteration   195; current loss is 1.2617411657219608
# Iteration   196; current loss is 0.8824667078182604
# Iteration   197; current loss is 0.8284521581868689
# Iteration   198; current loss is 0.8898037364422795
# Iteration   199; current loss is 0.9485250910273533
# Iteration   200; current loss is 1.0493474440819934
# Iteration   201; current loss is 1.1658714803091397
# Iteration   202; current loss is 0.9052341757074001
# Iteration   203; current loss is 1.1299169304594319
# Iteration   204; current loss is 1.06615266666142
# Iteration   205; current loss is 0.8240724631209
# Iteration   206; current loss is 1.295508949948342
# Iteration   207; current loss is 1.5032001117249743
# Iteration   208; current loss is 1.1854341081486843
# Iteration   209; current loss is 1.2302161831239204
# Iteration   210; current loss is 1.196912098485887
# Iteration   211; current loss is 0.9255051823797151
# Iteration   212; current loss is 1.4111493526942729
# Iteration   213; current loss is 1.1430135762452147
# Iteration   214; current loss is 1.0826315942073883
# Iteration   215; current loss is 1.3683347382906146
# Iteration   216; current loss is 0.5618229004349767
# Iteration   217; current loss is 0.5228724472669999
# Iteration   218; current loss is 1.0253092411556763
# Iteration   219; current loss is 0.7331646664120849
# Iteration   220; current loss is 0.844762414114915
# Iteration   221; current loss is 0.5742114610640346
# Iteration   222; current loss is 1.100662388992872
# Iteration   223; current loss is 0.9510566511151891
# Iteration   224; current loss is 0.6761807621462175
# Iteration   225; current loss is 0.5982547843206738
# Iteration   226; current loss is 0.9023927669138727
# Iteration   227; current loss is 1.0321974810915047
# Iteration   228; current loss is 0.6181682486833581
# Iteration   229; current loss is 0.544572458542372
# Iteration   230; current loss is 0.6700736966856325
# Iteration   231; current loss is 0.9518525411171868
# Iteration   232; current loss is 0.8883814044188005
# Iteration   233; current loss is 0.34776254825458186
# Iteration   234; current loss is 0.9094724831405174
# Iteration   235; current loss is 0.564427647118775
# Iteration   236; current loss is 0.7802589795935049
# Iteration   237; current loss is 0.3561178381012088
# Iteration   238; current loss is 0.9010800223891737
# Iteration   239; current loss is 0.5093515796464257
# Iteration   240; current loss is 0.38413926223368977
# Iteration   241; current loss is 0.3648477852390617
# Iteration   242; current loss is 0.8944189420136647
# Iteration   243; current loss is 0.3298834047580376
# Iteration   244; current loss is 0.7932248409340406
# Iteration   245; current loss is 0.4858069930738955
# Iteration   246; current loss is 0.8708390547909304
# Iteration   247; current loss is 0.7076595279057425
# Iteration   248; current loss is 0.5097370986843728
# Iteration   249; current loss is 0.6362338810735947
# Iteration   250; current loss is 0.7796566316963331
# Iteration   251; current loss is 0.6664409051203468
# Iteration   252; current loss is 0.6359117770214611
# Iteration   253; current loss is 0.48325720371901065
# Iteration   254; current loss is 0.5438523821692514
# Iteration   255; current loss is 0.42840812553535057
# Iteration   256; current loss is 0.4437903822451986
# Iteration   257; current loss is 0.765785500592195
# Iteration   258; current loss is 0.5029354559709526
# Iteration   259; current loss is 0.8218639200787297
# Iteration   260; current loss is 0.4694386320310616
# Iteration   261; current loss is 0.6821252705919305
# Iteration   262; current loss is 0.49829657303130315
# Iteration   263; current loss is 0.501937929829412
# Iteration   264; current loss is 0.7000738462368071
# Iteration   265; current loss is 0.8029672210190646
# Iteration   266; current loss is 0.4510148123201032
# Iteration   267; current loss is 0.8291893463407145
# Iteration   268; current loss is 0.9654196774693617
# Iteration   269; current loss is 0.9288792297462929
# Iteration   270; current loss is 0.38674845219236975
# Iteration   271; current loss is 0.5057100336826676
# Iteration   272; current loss is 0.7107826129536294
# Iteration   273; current loss is 0.925964667234169
# Iteration   274; current loss is 0.5103333638510485
# Iteration   275; current loss is 0.5015780356673304
# Iteration   276; current loss is 0.36044743260188306
# Iteration   277; current loss is 0.5242820594415959
# Iteration   278; current loss is 0.6241996275790038
# Iteration   279; current loss is 0.9135806951592594
# Iteration   280; current loss is 0.4145503196595365
# Iteration   281; current loss is 0.41066117884776016
# Iteration   282; current loss is 0.4944861191989693
# Iteration   283; current loss is 0.7003495640128277
# Iteration   284; current loss is 0.46498005158176736
# Iteration   285; current loss is 0.5091617444844156
# Iteration   286; current loss is 0.38061134045879763
# Iteration   287; current loss is 0.8307956719767746
# Iteration   288; current loss is 0.3040249457601216
# Iteration   289; current loss is 0.5232592019345548
# Iteration   290; current loss is 0.32143419613190227
# Iteration   291; current loss is 0.3455939369157335
# Iteration   292; current loss is 0.46373695765382267
# Iteration   293; current loss is 0.4351820479118629
# Iteration   294; current loss is 0.4613257602449339
# Iteration   295; current loss is 0.6465312306289808
# Iteration   296; current loss is 0.44914070113173
# Iteration   297; current loss is 0.6448748949069052
# Iteration   298; current loss is 0.20851404384774985
# Iteration   299; current loss is 0.32374763473914536
# Iteration   300; current loss is 0.5242111509910927
# Iteration   301; current loss is 0.6230691065640477
# Iteration   302; current loss is 0.2648579800049493
# Iteration   303; current loss is 0.5569607209008154
# Iteration   304; current loss is 0.41740745101141413
# Iteration   305; current loss is 0.6222930089792148
# Iteration   306; current loss is 0.3955454249699455
# Iteration   307; current loss is 0.4483161028961582
# Iteration   308; current loss is 0.60037464382881
# Iteration   309; current loss is 0.3480736702189437
# Iteration   310; current loss is 0.3529832042505202
# Iteration   311; current loss is 0.35288746386427844
# Iteration   312; current loss is 0.5198077861260458
# Iteration   313; current loss is 0.5998233506028252
# Iteration   314; current loss is 0.3750308537002507
# Iteration   315; current loss is 0.46070274811470857
# Iteration   316; current loss is 0.4026766743789443
# Iteration   317; current loss is 0.3187708484506909
# Iteration   318; current loss is 0.3122480810469674
# Iteration   319; current loss is 0.4372538958896436
# Iteration   320; current loss is 0.7885738476728541
# Iteration   321; current loss is 0.4232570571482175
# Iteration   322; current loss is 0.45263706528397074
# Iteration   323; current loss is 0.4324248386984143
# Iteration   324; current loss is 0.30026424737147345
# Iteration   325; current loss is 0.43667930934063975
# Iteration   326; current loss is 0.6441151090978188
# Iteration   327; current loss is 0.3519620966653534
# Iteration   328; current loss is 0.5334134663857777
# Iteration   329; current loss is 0.33981900242072194
# Iteration   330; current loss is 0.26408923153520253
# Iteration   331; current loss is 0.4036743799771363
# Iteration   332; current loss is 0.42366471307507986
# Iteration   333; current loss is 0.42102050274155456
# Iteration   334; current loss is 0.3158497993953382
# Iteration   335; current loss is 0.2955977415368306
# Iteration   336; current loss is 0.4779286949254207
# Iteration   337; current loss is 0.5176896032898697
# Iteration   338; current loss is 0.39212761553600367
# Iteration   339; current loss is 0.3223576085165698
# Iteration   340; current loss is 0.4652674494896324
# Iteration   341; current loss is 0.4423969088178022
# Iteration   342; current loss is 0.15413046500072314
# Iteration   343; current loss is 0.7039385270402185
# Iteration   344; current loss is 0.5372712127694059
# Iteration   345; current loss is 0.43221079491717573
# Iteration   346; current loss is 0.24915646800042382
# Iteration   347; current loss is 0.21455032413163225
# Iteration   348; current loss is 0.34811445319602174
# Iteration   349; current loss is 0.2888064826742639
# Iteration   350; current loss is 0.4989315607589555
# Iteration   351; current loss is 0.24074293310663314
# Iteration   352; current loss is 0.33211401351312897
# Iteration   353; current loss is 0.39187847848897495
# Iteration   354; current loss is 0.3444215265876539
# Iteration   355; current loss is 0.3045596592008312
# Iteration   356; current loss is 0.3001232366112856
# Iteration   357; current loss is 0.31654162814362263
# Iteration   358; current loss is 0.2682452824534792
# Iteration   359; current loss is 0.2467709441044118
# Iteration   360; current loss is 0.2628878473803815
# Iteration   361; current loss is 0.3968216432512517
# Iteration   362; current loss is 0.4142314672668181
# Iteration   363; current loss is 0.38550222870022754
# Iteration   364; current loss is 0.4127438786233498
# Iteration   365; current loss is 0.310195759787395
# Iteration   366; current loss is 0.5376910900627525
# Iteration   367; current loss is 0.42343208329422943
# Iteration   368; current loss is 0.24020227824815785
# Iteration   369; current loss is 0.4683670128612236
# Iteration   370; current loss is 0.360728009487433
# Iteration   371; current loss is 0.4503450532136115
# Iteration   372; current loss is 0.49613140798735683
# Iteration   373; current loss is 0.5440688704530625
# Iteration   374; current loss is 0.2971333582171779
# Iteration   375; current loss is 0.2542394905237437
# Iteration   376; current loss is 0.4527201430571769
# Iteration   377; current loss is 0.4959451901479695
# Iteration   378; current loss is 0.29963008027799265
# Iteration   379; current loss is 0.28449371949297075
# Iteration   380; current loss is 0.2881373228546713
# Iteration   381; current loss is 0.44173443350311997
# Iteration   382; current loss is 0.4398835226982607
# Iteration   383; current loss is 0.23701060017138023
# Iteration   384; current loss is 0.26417797399921894
# Iteration   385; current loss is 0.2575345306169026
# Iteration   386; current loss is 0.47066340336627865
# Iteration   387; current loss is 0.6865636039744727
# Iteration   388; current loss is 0.5422796856365719
# Iteration   389; current loss is 0.22627860821065993
# Iteration   390; current loss is 0.36024923517751417
# Iteration   391; current loss is 0.33077828056413683
# Iteration   392; current loss is 0.12981246145635425
# Iteration   393; current loss is 0.44389189674020557
# Iteration   394; current loss is 0.3970029077716204
# Iteration   395; current loss is 0.24004264997841335
# Iteration   396; current loss is 0.21159505192705896
# Iteration   397; current loss is 0.16222952298861837
# Iteration   398; current loss is 0.30360559917346325
# Iteration   399; current loss is 0.2127520886802466
# Iteration   400; current loss is 0.2961057437224953
# Iteration   401; current loss is 0.3144333017498683
# Iteration   402; current loss is 0.350079502819304
# Iteration   403; current loss is 0.22957834674164534
# Iteration   404; current loss is 0.17245692090294562
# Iteration   405; current loss is 0.20271519145956365
# Iteration   406; current loss is 0.19208305276204324
# Iteration   407; current loss is 0.3910520596178515
# Iteration   408; current loss is 0.17822375529392143
# Iteration   409; current loss is 0.3791742020562189
# Iteration   410; current loss is 0.43069988351554445
# Iteration   411; current loss is 0.26874103955551976
# Iteration   412; current loss is 0.24521815260653557
# Iteration   413; current loss is 0.5396228276734188
# Iteration   414; current loss is 0.6331506779235239
# Iteration   415; current loss is 0.2528570112691729
# Iteration   416; current loss is 0.14492951400550635
# Iteration   417; current loss is 0.15019105867966304
# Iteration   418; current loss is 0.1378049137743482
# Iteration   419; current loss is 0.3101479580834312
# Iteration   420; current loss is 0.2570307898657453
# Iteration   421; current loss is 0.25889037015724425
# Iteration   422; current loss is 0.16660819415099729
# Iteration   423; current loss is 0.21117438403920583
# Iteration   424; current loss is 0.22313116864231064
# Iteration   425; current loss is 0.2079345970702205
# Iteration   426; current loss is 0.28187264138671175
# Iteration   427; current loss is 0.25787284258330145
# Iteration   428; current loss is 0.1780189485567465
# Iteration   429; current loss is 0.31929154477010613
# Iteration   430; current loss is 0.2452774397279301
# Iteration   431; current loss is 0.34170275855462046
# Iteration   432; current loss is 0.2895851181800617
# Iteration   433; current loss is 0.3204622187484787
# Iteration   434; current loss is 0.24512801543120588
# Iteration   435; current loss is 0.30472738979555913
# Iteration   436; current loss is 0.25699822481139933
# Iteration   437; current loss is 0.1793207856562185
# Iteration   438; current loss is 0.21276677326994253
# Iteration   439; current loss is 0.2513901366250201
# Iteration   440; current loss is 0.24572695849936133
# Iteration   441; current loss is 0.2376624573367413
# Iteration   442; current loss is 0.42847163183791315
# Iteration   443; current loss is 0.36893693208668565
# Iteration   444; current loss is 0.22556120306176478
# Iteration   445; current loss is 0.2516494905358892
# Iteration   446; current loss is 0.33980045784428625
# Iteration   447; current loss is 0.32688498596151216
# Iteration   448; current loss is 0.3236573844554656
# Iteration   449; current loss is 0.250339389896104
# Iteration   450; current loss is 0.3275742850005516
# Iteration   451; current loss is 0.26298385551444864
# Iteration   452; current loss is 0.3000757022529116
# Iteration   453; current loss is 0.3690004451262
# Iteration   454; current loss is 0.3860324704123972
# Iteration   455; current loss is 0.3196621825234638
# Iteration   456; current loss is 0.24742428463445404
# Iteration   457; current loss is 0.16185949330607513
# Iteration   458; current loss is 0.22876558058149987
# Iteration   459; current loss is 0.3304222064142759
# Iteration   460; current loss is 0.20721911488277053
# Iteration   461; current loss is 0.30118793999399335
# Iteration   462; current loss is 0.2836362818458463
# Iteration   463; current loss is 0.34211085120951273
# Iteration   464; current loss is 0.23591100642829396
# Iteration   465; current loss is 0.3078500783357323
# Iteration   466; current loss is 0.19654794729056865
# Iteration   467; current loss is 0.35134850207983515
# Iteration   468; current loss is 0.37385217961040856
# Iteration   469; current loss is 0.3343683923832593
# Iteration   470; current loss is 0.2504329798265672
# Iteration   471; current loss is 0.2602538629292968
# Iteration   472; current loss is 0.1736671921032535
# Iteration   473; current loss is 0.36607863827669906
# Iteration   474; current loss is 0.3933768753185412
# Iteration   475; current loss is 0.40179758194668425
# Iteration   476; current loss is 0.2899519697699052
# Iteration   477; current loss is 0.2633289657204857
# Iteration   478; current loss is 0.28960702535087895
# Iteration   479; current loss is 0.18771693815431462
# Iteration   480; current loss is 0.22029211449272945
# Iteration   481; current loss is 0.1851202427252756
# Iteration   482; current loss is 0.2922716487087938
# Iteration   483; current loss is 0.4446521745822205
# Iteration   484; current loss is 0.42497220461619767
# Iteration   485; current loss is 0.2803571206247479
# Iteration   486; current loss is 0.2676961033612348
# Iteration   487; current loss is 0.27520714904710225
# Iteration   488; current loss is 0.3543924479576062
# Iteration   489; current loss is 0.27820289315974134
# Iteration   490; current loss is 0.2935025741117166
# Iteration   491; current loss is 0.23047314646112407
# Iteration   492; current loss is 0.35942014466168937
# Iteration   493; current loss is 0.27708107227487655
# Iteration   494; current loss is 0.26847782378572405
# Iteration   495; current loss is 0.5028130647519045
# Iteration   496; current loss is 0.4999005975371944
# Iteration   497; current loss is 0.23389719773095638
# Iteration   498; current loss is 0.30984673968000437
# Iteration   499; current loss is 0.2633529373133282
# Iteration   500; current loss is 0.21807193585069418
# Iteration   501; current loss is 0.3342430512221337
# Iteration   502; current loss is 0.32279755314682246
# Iteration   503; current loss is 0.23654537812957652
# Iteration   504; current loss is 0.2289266544420149
# Iteration   505; current loss is 0.18136030354766147
# Iteration   506; current loss is 0.23560565735238231
# Iteration   507; current loss is 0.18075830686640076
# Iteration   508; current loss is 0.11300195084103118
# Iteration   509; current loss is 0.3741477051073231
# Iteration   510; current loss is 0.3207565243458469
# Iteration   511; current loss is 0.30687788723099485
# Iteration   512; current loss is 0.2299846909767539
# Iteration   513; current loss is 0.5957228854402361
# Iteration   514; current loss is 0.46664636636202705
# Iteration   515; current loss is 0.2763036508789866
# Iteration   516; current loss is 0.27986982816740075
# Iteration   517; current loss is 0.28884104206732586
# Iteration   518; current loss is 0.21782778082532367
# Iteration   519; current loss is 0.2770851106462988
# Iteration   520; current loss is 0.3108671978583114
# Iteration   521; current loss is 0.21314024887574523
# Iteration   522; current loss is 0.2515242627429917
# Iteration   523; current loss is 0.414450123218834
# Iteration   524; current loss is 0.19282418004414853
# Iteration   525; current loss is 0.18194484019662344
# Iteration   526; current loss is 0.22433869163884745
# Iteration   527; current loss is 0.4329746731142782
# Iteration   528; current loss is 0.26000655151126595
# Iteration   529; current loss is 0.34302279831198523
# Iteration   530; current loss is 0.2698619648851483
# Iteration   531; current loss is 0.2488376823168023
# Iteration   532; current loss is 0.31398924403225853
# Iteration   533; current loss is 0.14190955460819418
# Iteration   534; current loss is 0.20674073881746902
# Iteration   535; current loss is 0.2520181757498598
# Iteration   536; current loss is 0.31114879621951985
# Iteration   537; current loss is 0.35843646152858843
# Iteration   538; current loss is 0.5331272340341182
# Iteration   539; current loss is 0.1421554652018463
# Iteration   540; current loss is 0.23428354068782467
# Iteration   541; current loss is 0.2776769155376506
# Iteration   542; current loss is 0.29956365244171845
# Iteration   543; current loss is 0.17802929731957104
# Iteration   544; current loss is 0.23576540892737685
# Iteration   545; current loss is 0.24868161486996793
# Iteration   546; current loss is 0.29981612868098
# Iteration   547; current loss is 0.40914059843870787
# Iteration   548; current loss is 0.41528798773731207
# Iteration   549; current loss is 0.431915645751047
# Iteration   550; current loss is 0.39761038536724985
# Iteration   551; current loss is 0.21194543538165875
# Iteration   552; current loss is 0.24778841782403538
# Iteration   553; current loss is 0.29299210910359963
# Iteration   554; current loss is 0.2895872234916722
# Iteration   555; current loss is 0.2853411677326865
# Iteration   556; current loss is 0.21988114267615919
# Iteration   557; current loss is 0.13035514100873746
# Iteration   558; current loss is 0.2044355924526311
# Iteration   559; current loss is 0.26119734376469006
# Iteration   560; current loss is 0.2846020659608661
# Iteration   561; current loss is 0.17310995274915222
# Iteration   562; current loss is 0.1784780996475243
# Iteration   563; current loss is 0.13561079978263796
# Iteration   564; current loss is 0.12134733375099804
# Iteration   565; current loss is 0.2937835496785548
# Iteration   566; current loss is 0.1870974371150872
# Iteration   567; current loss is 0.16477296909995176
# Iteration   568; current loss is 0.15950589716027747
# Iteration   569; current loss is 0.25889504483867765
# Iteration   570; current loss is 0.43934701382086927
# Iteration   571; current loss is 0.3106747022307499
# Iteration   572; current loss is 0.33050526452535695
# Iteration   573; current loss is 0.4155628634340091
# Iteration   574; current loss is 0.602952208414256
# Iteration   575; current loss is 0.2828934219629929
# Iteration   576; current loss is 0.26601639585995973
# Iteration   577; current loss is 0.3323529318406875
# Iteration   578; current loss is 0.3179455494602369
# Iteration   579; current loss is 0.3884210857992493
# Iteration   580; current loss is 0.5033739223582028
# Iteration   581; current loss is 0.23952832597221907
# Iteration   582; current loss is 0.2851443099152703
# Iteration   583; current loss is 0.4576294301744117
# Iteration   584; current loss is 0.3696342247733454
# Iteration   585; current loss is 0.16257840785904176
# Iteration   586; current loss is 0.5073570980712592
# Iteration   587; current loss is 0.2597688437939676
# Iteration   588; current loss is 0.297862921946221
# Iteration   589; current loss is 0.5044816031016682
# Iteration   590; current loss is 0.43497995211500773
# Iteration   591; current loss is 0.21850714910463048
# Iteration   592; current loss is 0.26201452198626896
# Iteration   593; current loss is 0.2647836362802491
# Iteration   594; current loss is 0.3403161332701982
# Iteration   595; current loss is 0.20189629174448773
# Iteration   596; current loss is 0.2316432707331291
# Iteration   597; current loss is 0.37672836248248875
# Iteration   598; current loss is 0.3743853958103138
# Iteration   599; current loss is 0.4522553392360323
# Iteration   600; current loss is 0.3543002578267753
# Iteration   601; current loss is 0.21488223327102723
# Iteration   602; current loss is 0.32822837378586933
# Iteration   603; current loss is 0.19861352815276234
# Iteration   604; current loss is 0.2348653610036675
# Iteration   605; current loss is 0.22278854516383698
# Iteration   606; current loss is 0.15494351456131464
# Iteration   607; current loss is 0.21342829781588935
# Iteration   608; current loss is 0.33382888843577546
# Iteration   609; current loss is 0.21111694313739912
# Iteration   610; current loss is 0.14883403945291832
# Iteration   611; current loss is 0.44133304563693976
# Iteration   612; current loss is 0.3158141192354501
# Iteration   613; current loss is 0.18528869412891547
# Iteration   614; current loss is 0.17218656874437865
# Iteration   615; current loss is 0.40602169630393425
# Iteration   616; current loss is 0.597993611140982
# Iteration   617; current loss is 0.3942833867177863
# Iteration   618; current loss is 0.22018459902593446
# Iteration   619; current loss is 0.19128862875455227
# Iteration   620; current loss is 0.20108804389963353
# Iteration   621; current loss is 0.2450194461951561
# Iteration   622; current loss is 0.4041477895226605
# Iteration   623; current loss is 0.15420787497217084
# Iteration   624; current loss is 0.2279254951874886
# Iteration   625; current loss is 0.28292493639137006
# Iteration   626; current loss is 0.3175085649910814
# Iteration   627; current loss is 0.23596511618522942
# Iteration   628; current loss is 0.20381815630814099
# Iteration   629; current loss is 0.2523452864473691
# Iteration   630; current loss is 0.135235071343832
# Iteration   631; current loss is 0.2894923848315485
# Iteration   632; current loss is 0.38854325545089785
# Iteration   633; current loss is 0.2775229487038531
# Iteration   634; current loss is 0.3019564605057323
# Iteration   635; current loss is 0.26948540848207714
# Iteration   636; current loss is 0.4348422260976296
# Iteration   637; current loss is 0.3783428715382178
# Iteration   638; current loss is 0.4064313357070412
# Iteration   639; current loss is 0.2501531840835367
# Iteration   640; current loss is 0.21252434681714152
# Iteration   641; current loss is 0.26212549980784655
# Iteration   642; current loss is 0.2762636115226872
# Iteration   643; current loss is 0.2828169277222135
# Iteration   644; current loss is 0.2318344241779407
# Iteration   645; current loss is 0.4848942179033928
# Iteration   646; current loss is 0.37600262611364677
# Iteration   647; current loss is 0.24178554882462602
# Iteration   648; current loss is 0.3257251436781463
# Iteration   649; current loss is 0.640547547052118
# Iteration   650; current loss is 0.7849549140829262
# Iteration   651; current loss is 0.10568153218406916
# CPU times: user 1min 5s, sys: 4min 17s, total: 5min 22s
# Wall time: 20.4 s

# %%
fig, ax = plt.subplots()
ax.plot(loss_values, label=f"KL Loss")
# plt.ylim(0, 30)
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.set_title(f"Loss Function over Iterations - Alternating Ansatz + KL divergence")
ax.legend()

# fig.savefig("loss_curve.png")

# %%
def simulate_circ(circ):
    """
    Generates our estimate state |phi> via simulation
    :param circ: qiskit.QuantumCircuit object, the variational quantum circuit
    :return: qiskit.Statevector object, represents our estimated quantum state |phi>
    """

    simulator = AerSimulator(method='statevector')
    circ.save_statevector() 
    job = simulator.run(circ)
    result = job.result()
    circ_statevect = Statevector(result.get_statevector(circ))
    
    return circ_statevect

def compute_fidelity(psi, phi):
    """
    Compute the fidelity (a measure of similarity) between the two states
    :param psi: qiskit.Statevector, our target state |psi>
    :param phi: qiskit.Statevector, our estimated state |phi>
    :return: float, fidelity
    """

    fidelity = qiskit.quantum_info.state_fidelity(psi, phi)
    print(f"psi: {psi}, phi: {phi}")
    # fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    # plot_bloch_multivector(psi)
    # axes[0].set_title("psi")
    # plot_bloch_multivector(phi)
    # axes[1].set_title("phi")
    return fidelity



ghz_state = Statevector.from_instruction(ghz_circ)
ansatz_state = Statevector.from_instruction(ansatz.assign_parameters({param_vec : results.x}))

final_fidelity = qiskit.quantum_info.state_fidelity(ghz_state, ansatz_state)

# %%
print(f"ghz state: {ghz_state}\nansatz: {ansatz_state}")
# Out:
# ghz state: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.70710678+0.j],
#             dims=(2, 2, 2))
# ansatz: Statevector([-0.31716247+0.65240967j,  0.0153138 -0.00839922j,
#              -0.01988269-0.04820247j,  0.0245004 -0.00087746j,
#              -0.0161913 +0.02149074j,  0.01463626+0.02021281j,
#               0.02185301+0.05239697j, -0.22603192+0.64380469j],
#             dims=(2, 2, 2))

# %%
print(final_fidelity)
# Out:
# 0.9876159048939134

# %%
print(results.x)
# Out:
# [ 1.96144039  0.72676817  0.01467313  4.08426616  2.18439344 -1.56224554
#  -1.78191138 -3.15332803  0.39244174  1.02873989  5.35848621 -4.70593488
#  -2.81221616  2.42862798 -0.61030087  0.0445544  -1.47079438  3.24603803
#   4.82813787 -3.29969042  2.78496717 -1.77396887 -0.31541314  3.79553977
#  -1.15949053 -0.58270074 -0.11735331  6.48540258 -2.19280273 -0.93908783]

# %%
np.save(f"saved/params_training_s{trial}.npy", thetas)
np.save(f"saved/loss_training_s{trial}.npy", loss_values)
np.save(f"saved/final_theta_s{trial}.npy", results.x)
np.save(f"saved/fidelity_s{trial}.npy", final_fidelity)

# %%
plot_state_city(ghz_state)

# %%
plot_state_city(ansatz_state)
