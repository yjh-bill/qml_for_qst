# %%
import os
from math import pi
import numpy as np
import random
import itertools
import scipy.optimize as opt
import matplotlib.pyplot as plt
import qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
# from qiskit_aer.noise import NoiseModel
# from qiskit_ibm_provider import IBMProvider


from ground_state import get_ground_state, measure_gs_basis_list

# %%
shots = 100
epsilon_loss = 1e-3 # loss added if test_counts entry is not found
epsilon_parameters=0.1 # scaling factor for initial random parameters (chosen between 0 to 2pi otherwise)

n_qubits = 3
n_bases = 15
depth = 10

delta = 1.0
h = 1.0
J = 1.0

max_iter = 1000

param_name = "theta"

# save checkpoints in case the connection to qpu breaks
# useful for running on real qpu, but not necessary for local simulation
have_checkpoints = False
checkpoint_path = None

# seed = 1000
trial = 0

# %%
# random.seed(seed)
rng = np.random.default_rng()

# %%
# backend = AerSimulator()
# sampler = Sampler.from_backend(backend)
# pm = generate_preset_pass_manager(backend=backend)

simulator_ideal = AerSimulator()
# simulator_ideal.set_options(seed_simulator=seed)
# sampler_ideal = Sampler.from_backend(simulator_ideal)
pm_ideal = generate_preset_pass_manager(backend=simulator_ideal, optimization_level=1)

# sampler = sampler_ideal
pm = pm_ideal

# %%
def create_ghz_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n - 1):
        qc.cx(i, i + 1)
    return qc

def get_circ_for_basis(qc: QuantumCircuit, basis: str):
    circ = qc.copy()
    for i, s in enumerate(basis[::-1]): # here, I am using the same endian convention as qiskit, where the last bit represent the first qubit
        if s == 'Z':
            pass
        elif s == 'X':
            circ.ry(-pi/2, i)
        elif s == 'Y':
            circ.rx(pi/2, i)
        else:
            raise ValueError(f"{s} is invalid basis")

    circ.measure_all()

    return circ

def get_isa_circ_list_for_bases(qc: QuantumCircuit, basis_list, pass_manager):
    circ_list = [get_circ_for_basis(qc, basis) for basis in basis_list]
    isa_circ_list = pass_manager.run(circ_list)
    return isa_circ_list


def measure_isa_circ_list_fs(isa_circ_list, basis_list, shots=shots):
    sampler = Sampler( )
    result_list = sampler.run(isa_circ_list, shots=shots).result()
    counts_list = [result.data.meas.get_counts() for result in result_list]
    results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    return results_dic


def get_basis_list(n_bases,n_qubits):
    bases = ["X", "Y", "Z"]
    basis_list = ["".join(p) for p in itertools.product(bases, repeat=n_qubits)]
    culled_basis_list = random.sample(basis_list, n_bases)
    return culled_basis_list




# def measure_circ_for_all_basis(qc, basis_list, shots=total_shots, sampler=None):
#     results_dic = {}
#     qc_list = [get_circ_for_basis(qc, basis, simulator) for basis in basis_list]
#     job = simulator.run(qc_list, shots=shots)
#     result = job.result()
#     counts_list = result.get_counts()
#     results_dic = {basis:counts for (basis, counts) in zip(basis_list, counts_list)}
    
#     return results_dic

# %%
basis_list = get_basis_list(n_bases, n_qubits)

# %%
gs_state = get_ground_state(n_qubits, delta=delta, h=h, J=J)
gs_measurements = measure_gs_basis_list(n_qubits, basis_list, shots, delta=delta, h=h, J=J)

# %%
print(basis_list)
# Out:
# ['YYZ', 'ZXZ', 'YZX', 'XZX', 'YZY', 'XYX', 'XYY', 'ZZZ', 'ZYZ', 'ZXX', 'XZY', 'YYY', 'YXY', 'ZZX', 'ZYY']

# %%
print(gs_measurements)
# Out:
# {'YYZ': {'000': 2, '001': 3, '010': 7, '011': 41, '100': 2, '101': 34, '110': 5, '111': 6}, 'ZXZ': {'001': 9, '011': 5, '100': 9, '101': 29, '110': 9, '111': 39}, 'YZX': {'000': 16, '001': 15, '010': 8, '011': 6, '100': 24, '101': 14, '110': 8, '111': 9}, 'XZX': {'000': 15, '001': 11, '010': 18, '100': 24, '101': 16, '111': 16}, 'YZY': {'000': 17, '001': 15, '010': 16, '100': 19, '101': 14, '111': 19}, 'XYX': {'000': 22, '001': 7, '010': 14, '011': 10, '100': 5, '101': 15, '110': 13, '111': 14}, 'XYY': {'000': 4, '001': 19, '010': 20, '011': 4, '100': 6, '101': 23, '110': 18, '111': 6}, 'ZZZ': {'011': 18, '101': 64, '110': 18}, 'ZYZ': {'001': 6, '011': 6, '100': 13, '101': 40, '110': 7, '111': 28}, 'ZXX': {'000': 5, '001': 5, '010': 3, '011': 3, '100': 5, '101': 32, '110': 43, '111': 4}, 'XZY': {'000': 18, '001': 15, '010': 9, '011': 5, '100': 17, '101': 17, '110': 14, '111': 5}, 'YYY': {'001': 16, '010': 31, '011': 5, '100': 9, '101': 28, '110': 11}, 'YXY': {'000': 17, '001': 12, '010': 11, '011': 7, '100': 9, '101': 18, '110': 7, '111': 19}, 'ZZX': {'010': 9, '011': 10, '100': 37, '101': 25, '110': 9, '111': 10}, 'ZYY': {'000': 7, '001': 5, '010': 4, '011': 8, '100': 3, '101': 38, '110': 30, '111': 5}}

# %%
def initialize_theta_random(circ_depth=10, num_qbits=3):
    """
    Initialize the theta parameter vector
    :param circ_depth: int, number of parameterized layers in circuit
    :param num_qbits: int, number of qbits
    :return: np.array, values of theta
    """

    theta = rng.random(size=(circ_depth, num_qbits))
    theta = 2*pi*epsilon_parameters*theta
    return theta

# %%
def construct_variational_circ_ansatz(num_qbits, circ_depth, param_name = param_name):
    """
    Generate a parameterized variational quantum circuit
    
    """

    num_parameters = num_qbits * circ_depth
    theta_vec = ParameterVector(param_name, length=num_parameters)
    var_circ = QuantumCircuit(num_qbits)


    for layer in range(circ_depth - 1):
        # Compute if layer is odd or even to apply rx or ry gate to circuit
        is_odd_step = (layer + 1) % 2

        for qbit in range(num_qbits):
            if is_odd_step:
                var_circ.rx(theta_vec[layer * num_qbits + qbit], qbit)
            else:
                var_circ.ry(theta_vec[layer * num_qbits + qbit], qbit)

        # Apply CX gates
        for qbit in range((1-is_odd_step), num_qbits-1, 2):
            # isOddStep may subtract 1 if True, to correctly apply cx gate location
            var_circ.cx(qbit , qbit + 1)
            var_circ.barrier() # for visualization only

    for qbit in range(num_qbits):  # bonus layer at the end only has rx gates and no cx
        var_circ.rx(theta_vec[(circ_depth - 1) * num_qbits + qbit], qbit)

    return var_circ, theta_vec

# %%
ansatz, param_vec = construct_variational_circ_ansatz(n_qubits, depth, param_name=param_name)

# %%
ansatz.draw(output="mpl", style="clifford")

# %%
ansatz_isa_list = get_isa_circ_list_for_bases(ansatz, basis_list, pm)

# %%
def get_ansatz_output(ansatz_isa_list, parameters, basis_list, shots, param_placeholder=param_vec):
    circ_run_list = [circ.assign_parameters({param_placeholder:parameters}) for circ in ansatz_isa_list]
    return measure_isa_circ_list_fs(isa_circ_list=circ_run_list, basis_list=basis_list, shots=shots)

# %%
def KL_divergence(true_data, test_data, epsilon_loss = epsilon_loss):
    loss = 0

    # here, let me assume true data and test data can have different number of shots
    # but the shot in each basis should be the same
    true_data_total_shots = sum(list(true_data.values())[0].values())
    test_data_total_shots = sum(list(test_data.values())[0].values())

    for basis in true_data: # just a note that if there are hallucinated measurements in 
        # bases/states not included in the true data then the kl divergence will not account for these (at least as presented in the paper)
        for state in true_data[basis]:
            true_counts = true_data[basis][state]
            test_counts = test_data[basis].get(state, 0)
            true_prob   = true_counts / true_data_total_shots
            test_prob   = test_counts / test_data_total_shots
            loss += true_prob *(np.log((true_prob)/(test_prob +epsilon_loss)))

    return loss / len(true_data)

# %%
global loss_values
global thetas

loss_values = []
thetas = []

# %%
def compute_kl_loss(theta_vector, ansatz_isa_list,  basis_list, true_data, shots, param_placeholder=param_vec, \
        print_message=True, have_checkpoints=have_checkpoints, checkpoint_path=checkpoint_path):
    # theta = np.reshape(theta_vector, (circ_depth, num_qbits))
    # tempcirc = construct_variational_circ(theta=theta)
    test_data = get_ansatz_output(ansatz_isa_list=ansatz_isa_list, parameters=theta_vector, basis_list=basis_list, \
        shots=shots, param_placeholder=param_placeholder)
    # test_data = measure_circ_for_all_basis(qc = tempcirc, basis_list=basis_list, simulator=simulator)
    loss = KL_divergence(true_data, test_data) + \
        KL_divergence(test_data, true_data) # symmetrizing the loss

    global loss_values
    global thetas 
    loss_values.append(loss)
    thetas.append(theta_vector)

    num_iter = len(loss_values)

    if print_message:
        print(f"Iteration {num_iter:5}; current loss is {loss}")

    if have_checkpoints:
        # save checkpoints in case the connection to qpu breaks
        # useful for running on real qpu, but not necessary for local simulation
        np.save(os.path.join(checkpoint_path, f"theta_iter{num_iter}.npy"), thetas)
    
    return loss

# %%
from qiskit_algorithms.optimizers import SPSA

spsa = SPSA()
print(spsa.is_initial_point_ignored)
# Out:
# False

# %%
# wraps the function with the all arguments but theta vector already filled

def compute_kl_loss_filled(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, gs_measurements, shots, param_vec, print_message=True)

def compute_kl_loss_filled_quiet(theta_vector):
    return compute_kl_loss(theta_vector, ansatz_isa_list, basis_list, gs_measurements, shots, param_vec, print_message=False)

# %%
# %%time

theta = initialize_theta_random(circ_depth=depth, num_qbits = n_qubits)
theta_vector = np.reshape(theta, theta.size)
circ_depth, num_qbits = theta.shape

spsa = SPSA(maxiter=300)
# c=0.1258
# A=0.3186
# a1=0.4739
# alpha=0.6374
# gamma=0.06059
# (lr, p) = spsa.calibrate(compute_kl_loss_filled, theta_vector, c=c, stability_constant = A, target_magnitude=a1, alpha=alpha, gamma=gamma)
# spsa.learning_rate = lr
# spsa.perturbation = p

# args = (ansatz_isa_list, basis_list, GHZ_measurement, shots, param_vec)

# results = opt.minimize(compute_kl_loss, theta_vector, args = args, method = "Powell", options={"maxiter":max_iter})

results = spsa.minimize(compute_kl_loss_filled, theta_vector)
# Out:
# Iteration     1; current loss is 2.3622450655900824
# Iteration     2; current loss is 2.2871883467007983
# Iteration     3; current loss is 2.3697525693167827
# Iteration     4; current loss is 2.8325543326219673
# Iteration     5; current loss is 2.88720844941227
# Iteration     6; current loss is 1.8850354299347694
# Iteration     7; current loss is 2.302376913584899
# Iteration     8; current loss is 2.512943419469778
# Iteration     9; current loss is 2.6634553630589286
# Iteration    10; current loss is 1.9064285429408059
# Iteration    11; current loss is 3.088397874814714
# Iteration    12; current loss is 2.8268847077308976
# Iteration    13; current loss is 1.9093844651581469
# Iteration    14; current loss is 2.7603024514057566
# Iteration    15; current loss is 1.8742413643264384
# Iteration    16; current loss is 2.8046242169929005
# Iteration    17; current loss is 2.4786040029812506
# Iteration    18; current loss is 1.9898360669016641
# Iteration    19; current loss is 2.3989345334202694
# Iteration    20; current loss is 2.9088561378645785
# Iteration    21; current loss is 2.682772722109034
# Iteration    22; current loss is 2.3549886353549354
# Iteration    23; current loss is 2.5949755120612306
# Iteration    24; current loss is 1.8281400527294664
# Iteration    25; current loss is 2.534827121269479
# Iteration    26; current loss is 2.204900449013236
# Iteration    27; current loss is 1.8695470891862507
# Iteration    28; current loss is 3.0496723208786287
# Iteration    29; current loss is 2.37026764078371
# Iteration    30; current loss is 2.0286535540740145
# Iteration    31; current loss is 2.44824498836455
# Iteration    32; current loss is 2.688150434724892
# Iteration    33; current loss is 2.249758842349349
# Iteration    34; current loss is 2.4060409104515994
# Iteration    35; current loss is 2.426496938340308
# Iteration    36; current loss is 2.0901999482885323
# Iteration    37; current loss is 1.9413636702155532
# Iteration    38; current loss is 2.9784808367738145
# Iteration    39; current loss is 2.515966550966346
# Iteration    40; current loss is 2.2360439350125914
# Iteration    41; current loss is 2.105999973335367
# Iteration    42; current loss is 2.399132753743185
# Iteration    43; current loss is 1.957455138000594
# Iteration    44; current loss is 2.7842468883911327
# Iteration    45; current loss is 2.328776373519828
# Iteration    46; current loss is 3.057906161541042
# Iteration    47; current loss is 1.9353578374367144
# Iteration    48; current loss is 2.6795647912773592
# Iteration    49; current loss is 2.246201248447356
# Iteration    50; current loss is 2.2111390819333048
# Iteration    51; current loss is 2.3937518745866653
# Iteration    52; current loss is 2.645471481408466
# Iteration    53; current loss is 2.4503741001216817
# Iteration    54; current loss is 1.9593982348435417
# Iteration    55; current loss is 1.6742137444755352
# Iteration    56; current loss is 1.7160880922444077
# Iteration    57; current loss is 1.9399344478637688
# Iteration    58; current loss is 2.1531398696393156
# Iteration    59; current loss is 1.6555366314547966
# Iteration    60; current loss is 2.01574935702497
# Iteration    61; current loss is 2.0226146666574922
# Iteration    62; current loss is 1.4911345518321175
# Iteration    63; current loss is 1.7617950072348003
# Iteration    64; current loss is 1.5459786044076347
# Iteration    65; current loss is 1.4050099823934108
# Iteration    66; current loss is 1.544067267034015
# Iteration    67; current loss is 1.930585654794409
# Iteration    68; current loss is 1.1946606577502858
# Iteration    69; current loss is 1.4908444474146818
# Iteration    70; current loss is 1.5189694514690584
# Iteration    71; current loss is 1.8064128200332485
# Iteration    72; current loss is 1.210887005516019
# Iteration    73; current loss is 1.0998488002422755
# Iteration    74; current loss is 1.95079593406091
# Iteration    75; current loss is 1.602310183187286
# Iteration    76; current loss is 1.219088674508118
# Iteration    77; current loss is 0.9155175982088057
# Iteration    78; current loss is 1.5523869962666477
# Iteration    79; current loss is 1.0916226960210134
# Iteration    80; current loss is 1.3010557530532414
# Iteration    81; current loss is 1.3089917331583467
# Iteration    82; current loss is 1.2407145946575286
# Iteration    83; current loss is 1.2025050310765244
# Iteration    84; current loss is 1.3307075412234037
# Iteration    85; current loss is 0.9664344309055626
# Iteration    86; current loss is 1.295408774937087
# Iteration    87; current loss is 0.8720209191213464
# Iteration    88; current loss is 1.187631118299071
# Iteration    89; current loss is 0.8997456929032752
# Iteration    90; current loss is 1.1248570516070895
# Iteration    91; current loss is 1.1833272170900226
# Iteration    92; current loss is 0.9327882594623467
# Iteration    93; current loss is 0.8376701799301723
# Iteration    94; current loss is 0.8957142964795292
# Iteration    95; current loss is 0.9533809762144997
# Iteration    96; current loss is 1.082867106080295
# Iteration    97; current loss is 0.7399421251545153
# Iteration    98; current loss is 1.242871452095884
# Iteration    99; current loss is 0.8561283909021647
# Iteration   100; current loss is 0.9441883107534407
# Iteration   101; current loss is 0.7258481296923585
# Iteration   102; current loss is 1.1228210799087228
# Iteration   103; current loss is 0.7974970517430071
# Iteration   104; current loss is 0.6701444300912861
# Iteration   105; current loss is 0.7957887463744857
# Iteration   106; current loss is 0.8252390465453033
# Iteration   107; current loss is 0.9736467685898086
# Iteration   108; current loss is 0.9164866054771372
# Iteration   109; current loss is 0.8400626628086638
# Iteration   110; current loss is 1.1313617162202863
# Iteration   111; current loss is 0.8131602897526431
# Iteration   112; current loss is 1.550592269621074
# Iteration   113; current loss is 0.7986994454081413
# Iteration   114; current loss is 0.8771691406925599
# Iteration   115; current loss is 1.2109846140186014
# Iteration   116; current loss is 0.9928713151882107
# Iteration   117; current loss is 0.7325644704913707
# Iteration   118; current loss is 0.7483191382142326
# Iteration   119; current loss is 1.1836981048057376
# Iteration   120; current loss is 0.6500159233327216
# Iteration   121; current loss is 0.8306026939675734
# Iteration   122; current loss is 0.7015866169377897
# Iteration   123; current loss is 0.7400179425356398
# Iteration   124; current loss is 1.1817312363619397
# Iteration   125; current loss is 0.6072223149108285
# Iteration   126; current loss is 0.9684655211128139
# Iteration   127; current loss is 1.0762471532785212
# Iteration   128; current loss is 0.5300772252746736
# Iteration   129; current loss is 0.8788761401706435
# Iteration   130; current loss is 0.7131287452311961
# Iteration   131; current loss is 0.6793048586950111
# Iteration   132; current loss is 0.4902220891876853
# Iteration   133; current loss is 0.6472990126615592
# Iteration   134; current loss is 0.5305348799659592
# Iteration   135; current loss is 0.4596405879939237
# Iteration   136; current loss is 0.8811263539881456
# Iteration   137; current loss is 0.8794419793766532
# Iteration   138; current loss is 0.6921283060302417
# Iteration   139; current loss is 0.7326059015387776
# Iteration   140; current loss is 0.5794696159475135
# Iteration   141; current loss is 0.7209605148486199
# Iteration   142; current loss is 0.5171346310303797
# Iteration   143; current loss is 0.8290990152034405
# Iteration   144; current loss is 0.2928175091451838
# Iteration   145; current loss is 0.7647870487298258
# Iteration   146; current loss is 0.651069406264927
# Iteration   147; current loss is 0.6434170816188549
# Iteration   148; current loss is 0.534901169313029
# Iteration   149; current loss is 0.5417606149174743
# Iteration   150; current loss is 0.518558141465768
# Iteration   151; current loss is 0.3964683053249351
# Iteration   152; current loss is 0.7252382672864253
# Iteration   153; current loss is 0.4693776516661323
# Iteration   154; current loss is 0.6157418950524838
# Iteration   155; current loss is 0.36683171538478776
# Iteration   156; current loss is 0.4273055525368385
# Iteration   157; current loss is 0.7606334684768943
# Iteration   158; current loss is 0.698141441165357
# Iteration   159; current loss is 0.5268791850840394
# Iteration   160; current loss is 0.5708852708235073
# Iteration   161; current loss is 0.9402784030709754
# Iteration   162; current loss is 0.5720104554478982
# Iteration   163; current loss is 0.5464420433615884
# Iteration   164; current loss is 0.642177521153014
# Iteration   165; current loss is 1.1139597317455285
# Iteration   166; current loss is 0.5732359570614809
# Iteration   167; current loss is 0.8251878333421838
# Iteration   168; current loss is 0.4422239450283133
# Iteration   169; current loss is 0.48290701987667733
# Iteration   170; current loss is 0.5726824543780479
# Iteration   171; current loss is 0.3464362581565331
# Iteration   172; current loss is 0.74195073734901
# Iteration   173; current loss is 0.6925631567726631
# Iteration   174; current loss is 0.5824083454477789
# Iteration   175; current loss is 0.5343749607475445
# Iteration   176; current loss is 0.6165507880162779
# Iteration   177; current loss is 0.45623319503537296
# Iteration   178; current loss is 0.37672768687572883
# Iteration   179; current loss is 0.6101534996675415
# Iteration   180; current loss is 0.633046580642711
# Iteration   181; current loss is 0.5138623860160869
# Iteration   182; current loss is 0.7517180082754685
# Iteration   183; current loss is 0.5317731795198217
# Iteration   184; current loss is 0.734409791614544
# Iteration   185; current loss is 0.6536267145647308
# Iteration   186; current loss is 0.4440509235882507
# Iteration   187; current loss is 0.587163386383445
# Iteration   188; current loss is 0.5243257718299802
# Iteration   189; current loss is 0.6613883229775501
# Iteration   190; current loss is 0.6499880124733468
# Iteration   191; current loss is 0.6649774611882745
# Iteration   192; current loss is 0.5037777189345042
# Iteration   193; current loss is 0.4753122264443061
# Iteration   194; current loss is 0.5304118252130094
# Iteration   195; current loss is 0.5874277462267614
# Iteration   196; current loss is 0.593203375853967
# Iteration   197; current loss is 0.5503937834948041
# Iteration   198; current loss is 0.4632907181610771
# Iteration   199; current loss is 0.7451993255434044
# Iteration   200; current loss is 0.5862990522906063
# Iteration   201; current loss is 0.4512341088699191
# Iteration   202; current loss is 0.28615951429130426
# Iteration   203; current loss is 0.42624911969005946
# Iteration   204; current loss is 0.4032746388359621
# Iteration   205; current loss is 0.4465160738101037
# Iteration   206; current loss is 0.46900153859862537
# Iteration   207; current loss is 0.26972151639453323
# Iteration   208; current loss is 0.3887892443416627
# Iteration   209; current loss is 0.5163287004310742
# Iteration   210; current loss is 0.627439582938341
# Iteration   211; current loss is 0.4883229140857132
# Iteration   212; current loss is 0.5035271037289937
# Iteration   213; current loss is 0.6350056351127835
# Iteration   214; current loss is 0.6668123160076305
# Iteration   215; current loss is 0.37250841568498333
# Iteration   216; current loss is 0.32925078146272035
# Iteration   217; current loss is 0.5961181784506366
# Iteration   218; current loss is 0.7588844558243495
# Iteration   219; current loss is 0.8906675876705363
# Iteration   220; current loss is 0.45862009815185045
# Iteration   221; current loss is 0.7002766089432397
# Iteration   222; current loss is 0.3933027260547173
# Iteration   223; current loss is 0.5839858320742468
# Iteration   224; current loss is 0.284152793313175
# Iteration   225; current loss is 0.3692033401170257
# Iteration   226; current loss is 0.5057324221582338
# Iteration   227; current loss is 0.32102504676804505
# Iteration   228; current loss is 0.24085011490050984
# Iteration   229; current loss is 0.7944766255183806
# Iteration   230; current loss is 0.6129887383906475
# Iteration   231; current loss is 0.3658787861835381
# Iteration   232; current loss is 0.46190371204694214
# Iteration   233; current loss is 0.5850330141375941
# Iteration   234; current loss is 0.49797249910402097
# Iteration   235; current loss is 0.377436551622924
# Iteration   236; current loss is 0.4917813308979989
# Iteration   237; current loss is 0.34815631469609865
# Iteration   238; current loss is 0.4046106190043224
# Iteration   239; current loss is 0.4418482283778711
# Iteration   240; current loss is 0.3128046706234606
# Iteration   241; current loss is 0.36907163133848364
# Iteration   242; current loss is 0.7280498681966392
# Iteration   243; current loss is 0.5567578578817995
# Iteration   244; current loss is 0.6070510295896308
# Iteration   245; current loss is 0.584365877912935
# Iteration   246; current loss is 0.4016378993197026
# Iteration   247; current loss is 0.5263969755731146
# Iteration   248; current loss is 0.4995163239881258
# Iteration   249; current loss is 0.3616256935628222
# Iteration   250; current loss is 0.5004505576186035
# Iteration   251; current loss is 0.3979561717787916
# Iteration   252; current loss is 0.30107109969058604
# Iteration   253; current loss is 0.3329328368312524
# Iteration   254; current loss is 0.2977159734646505
# Iteration   255; current loss is 0.30272148765844775
# Iteration   256; current loss is 0.3432590367696109
# Iteration   257; current loss is 0.49573364162547845
# Iteration   258; current loss is 0.5945734888319241
# Iteration   259; current loss is 0.39209386457066875
# Iteration   260; current loss is 0.3974362184734289
# Iteration   261; current loss is 0.5887375033806097
# Iteration   262; current loss is 0.38284888199644956
# Iteration   263; current loss is 0.4786447659345773
# Iteration   264; current loss is 0.41054711218036233
# Iteration   265; current loss is 0.2835161110123575
# Iteration   266; current loss is 0.3343264607480505
# Iteration   267; current loss is 0.4328264764799248
# Iteration   268; current loss is 0.2803110044943465
# Iteration   269; current loss is 0.265521741864304
# Iteration   270; current loss is 0.3996782770655861
# Iteration   271; current loss is 0.46836615644802154
# Iteration   272; current loss is 0.5518292558625272
# Iteration   273; current loss is 0.41250709774217725
# Iteration   274; current loss is 0.368399518568153
# Iteration   275; current loss is 0.40708716156064334
# Iteration   276; current loss is 0.2687953143724521
# Iteration   277; current loss is 0.31766545914845207
# Iteration   278; current loss is 0.3053156386050365
# Iteration   279; current loss is 0.2627607195972871
# Iteration   280; current loss is 0.2239286611863841
# Iteration   281; current loss is 0.4458889984056793
# Iteration   282; current loss is 0.25533939852548826
# Iteration   283; current loss is 0.29552199624533393
# Iteration   284; current loss is 0.2818237768382593
# Iteration   285; current loss is 0.33062481943201893
# Iteration   286; current loss is 0.3289216358091056
# Iteration   287; current loss is 0.47620363861237724
# Iteration   288; current loss is 0.37996642429938043
# Iteration   289; current loss is 0.6433702270136551
# Iteration   290; current loss is 0.5754577257539625
# Iteration   291; current loss is 0.5106942057793487
# Iteration   292; current loss is 0.4867299911581072
# Iteration   293; current loss is 0.22759444334796436
# Iteration   294; current loss is 0.29067460498248177
# Iteration   295; current loss is 0.5104670354398825
# Iteration   296; current loss is 0.44896318713920685
# Iteration   297; current loss is 0.48054234501021825
# Iteration   298; current loss is 0.43540369441018856
# Iteration   299; current loss is 0.7413282640250658
# Iteration   300; current loss is 0.7415546628211397
# Iteration   301; current loss is 0.5796727453365171
# Iteration   302; current loss is 0.6381683345853069
# Iteration   303; current loss is 0.26918049500087643
# Iteration   304; current loss is 0.2698814713002971
# Iteration   305; current loss is 0.5009650126709102
# Iteration   306; current loss is 0.384130566992235
# Iteration   307; current loss is 0.3704015030669108
# Iteration   308; current loss is 0.3177836746953698
# Iteration   309; current loss is 0.4795216697886907
# Iteration   310; current loss is 0.65674630360478
# Iteration   311; current loss is 0.26953404735582276
# Iteration   312; current loss is 0.3778546934920781
# Iteration   313; current loss is 0.2571317021210533
# Iteration   314; current loss is 0.20453616718814438
# Iteration   315; current loss is 0.36003770183634654
# Iteration   316; current loss is 0.4603154774003492
# Iteration   317; current loss is 0.4251542684300318
# Iteration   318; current loss is 0.5204941880845961
# Iteration   319; current loss is 0.29995903024062565
# Iteration   320; current loss is 0.24934093385012063
# Iteration   321; current loss is 0.4664711604531081
# Iteration   322; current loss is 0.40078912762190344
# Iteration   323; current loss is 0.4284830839282907
# Iteration   324; current loss is 0.46765041126690854
# Iteration   325; current loss is 0.4740635069819681
# Iteration   326; current loss is 0.3636815723786218
# Iteration   327; current loss is 0.3617765797940795
# Iteration   328; current loss is 0.42110192416261605
# Iteration   329; current loss is 0.4437926417839394
# Iteration   330; current loss is 0.4238618555347836
# Iteration   331; current loss is 0.19349312468962593
# Iteration   332; current loss is 0.29107506914503356
# Iteration   333; current loss is 0.4356684596381025
# Iteration   334; current loss is 0.40019121001562263
# Iteration   335; current loss is 0.3578715589721225
# Iteration   336; current loss is 0.42286857343879175
# Iteration   337; current loss is 0.4700795609729461
# Iteration   338; current loss is 0.5649119899722428
# Iteration   339; current loss is 0.5181855011950284
# Iteration   340; current loss is 0.39151719916452665
# Iteration   341; current loss is 0.352686384547934
# Iteration   342; current loss is 0.38674119065399515
# Iteration   343; current loss is 0.46390451535305033
# Iteration   344; current loss is 0.40467436391167744
# Iteration   345; current loss is 0.5061332190971453
# Iteration   346; current loss is 0.6011885531615466
# Iteration   347; current loss is 0.36680490535060617
# Iteration   348; current loss is 0.29662437538631764
# Iteration   349; current loss is 0.3484114405223929
# Iteration   350; current loss is 0.20622236887253442
# Iteration   351; current loss is 0.5801731318123637
# Iteration   352; current loss is 0.39513513941811645
# Iteration   353; current loss is 0.43667870521979646
# Iteration   354; current loss is 0.6382378081156874
# Iteration   355; current loss is 0.33156207368131513
# Iteration   356; current loss is 0.2854637481165563
# Iteration   357; current loss is 0.2562316636263481
# Iteration   358; current loss is 0.2652204306388174
# Iteration   359; current loss is 0.29946278811139937
# Iteration   360; current loss is 0.33928346312011143
# Iteration   361; current loss is 0.46767075399564045
# Iteration   362; current loss is 0.5396059122164844
# Iteration   363; current loss is 0.30182254531523545
# Iteration   364; current loss is 0.344882948038089
# Iteration   365; current loss is 0.5702922015839599
# Iteration   366; current loss is 0.4205910330716408
# Iteration   367; current loss is 0.35614160780870896
# Iteration   368; current loss is 0.29540527136859707
# Iteration   369; current loss is 0.49032191504270395
# Iteration   370; current loss is 0.47028668394666684
# Iteration   371; current loss is 0.3564011458743858
# Iteration   372; current loss is 0.2959897536131103
# Iteration   373; current loss is 0.501678012897685
# Iteration   374; current loss is 0.47096645545815763
# Iteration   375; current loss is 0.43575590820694127
# Iteration   376; current loss is 0.4554783999886839
# Iteration   377; current loss is 0.285604131314637
# Iteration   378; current loss is 0.3207710627531685
# Iteration   379; current loss is 0.33035998983522924
# Iteration   380; current loss is 0.3225330047813981
# Iteration   381; current loss is 0.2667363968353046
# Iteration   382; current loss is 0.3342605228794687
# Iteration   383; current loss is 0.4395612178659771
# Iteration   384; current loss is 0.43663210509181793
# Iteration   385; current loss is 0.4639851482225905
# Iteration   386; current loss is 0.30431831883037996
# Iteration   387; current loss is 0.2692737905980223
# Iteration   388; current loss is 0.2412159025690458
# Iteration   389; current loss is 0.2915880218298792
# Iteration   390; current loss is 0.3464526069681399
# Iteration   391; current loss is 0.27758806051851925
# Iteration   392; current loss is 0.24522360831658024
# Iteration   393; current loss is 0.22973677274147242
# Iteration   394; current loss is 0.2954518505646536
# Iteration   395; current loss is 0.4424264840894905
# Iteration   396; current loss is 0.48078841670961814
# Iteration   397; current loss is 0.4365535426281248
# Iteration   398; current loss is 0.3868169779212489
# Iteration   399; current loss is 0.19664022522282296
# Iteration   400; current loss is 0.3292777147879805
# Iteration   401; current loss is 0.40075932377063195
# Iteration   402; current loss is 0.3528604204937923
# Iteration   403; current loss is 0.20118554473013334
# Iteration   404; current loss is 0.3417478167923776
# Iteration   405; current loss is 0.29106647148550646
# Iteration   406; current loss is 0.27994710916011334
# Iteration   407; current loss is 0.4500105137371043
# Iteration   408; current loss is 0.47559196263605186
# Iteration   409; current loss is 0.238129806375323
# Iteration   410; current loss is 0.21548666263623445
# Iteration   411; current loss is 0.6013022711107797
# Iteration   412; current loss is 0.7029963831034655
# Iteration   413; current loss is 0.2118185548478802
# Iteration   414; current loss is 0.33181314924506944
# Iteration   415; current loss is 0.1844108150803898
# Iteration   416; current loss is 0.2818340889551235
# Iteration   417; current loss is 0.23285517736548184
# Iteration   418; current loss is 0.3360752720398627
# Iteration   419; current loss is 0.2613961896584541
# Iteration   420; current loss is 0.22125831267400362
# Iteration   421; current loss is 0.23456481102023774
# Iteration   422; current loss is 0.2680330786260095
# Iteration   423; current loss is 0.28161543159791036
# Iteration   424; current loss is 0.27416086129537065
# Iteration   425; current loss is 0.2978176183212716
# Iteration   426; current loss is 0.30141928907016435
# Iteration   427; current loss is 0.3241769985989402
# Iteration   428; current loss is 0.40311180356675497
# Iteration   429; current loss is 0.2935388504353704
# Iteration   430; current loss is 0.24567473297315817
# Iteration   431; current loss is 0.329855131075276
# Iteration   432; current loss is 0.337786996004236
# Iteration   433; current loss is 0.36439743603800573
# Iteration   434; current loss is 0.39472797732753556
# Iteration   435; current loss is 0.5560915662404375
# Iteration   436; current loss is 0.4765237623013641
# Iteration   437; current loss is 0.26458315917485176
# Iteration   438; current loss is 0.3017714475800512
# Iteration   439; current loss is 0.35209808594270375
# Iteration   440; current loss is 0.19644875136118545
# Iteration   441; current loss is 0.3692703455504014
# Iteration   442; current loss is 0.23973905649956068
# Iteration   443; current loss is 0.3591409123907374
# Iteration   444; current loss is 0.42625689720305193
# Iteration   445; current loss is 0.2882995177609943
# Iteration   446; current loss is 0.24236389684034132
# Iteration   447; current loss is 0.20448851755738456
# Iteration   448; current loss is 0.23777651095755192
# Iteration   449; current loss is 0.4344223357767205
# Iteration   450; current loss is 0.4003997717378097
# Iteration   451; current loss is 0.23226831387231694
# Iteration   452; current loss is 0.24450956321510348
# Iteration   453; current loss is 0.31032519618311244
# Iteration   454; current loss is 0.29268903748928743
# Iteration   455; current loss is 0.2658469776367614
# Iteration   456; current loss is 0.28486638748517973
# Iteration   457; current loss is 0.35748865359947113
# Iteration   458; current loss is 0.37523284085997777
# Iteration   459; current loss is 0.5806049254170709
# Iteration   460; current loss is 0.5235877605322734
# Iteration   461; current loss is 0.3962802698308784
# Iteration   462; current loss is 0.4968237350699137
# Iteration   463; current loss is 0.1853772616886592
# Iteration   464; current loss is 0.22379776866326945
# Iteration   465; current loss is 0.32224219896314277
# Iteration   466; current loss is 0.3756978100553746
# Iteration   467; current loss is 0.4246638589951297
# Iteration   468; current loss is 0.45234187593272823
# Iteration   469; current loss is 0.3606172851809497
# Iteration   470; current loss is 0.2996930935790439
# Iteration   471; current loss is 0.4374775861851541
# Iteration   472; current loss is 0.45945026241570164
# Iteration   473; current loss is 0.20957142594748623
# Iteration   474; current loss is 0.1920559163178081
# Iteration   475; current loss is 0.5036865944233433
# Iteration   476; current loss is 0.6077524274163489
# Iteration   477; current loss is 0.3869848603167937
# Iteration   478; current loss is 0.3507731249224525
# Iteration   479; current loss is 0.2925198801640865
# Iteration   480; current loss is 0.2828497498405339
# Iteration   481; current loss is 0.47450521184445194
# Iteration   482; current loss is 0.4600440946934578
# Iteration   483; current loss is 0.30261267010994314
# Iteration   484; current loss is 0.3055018548987265
# Iteration   485; current loss is 0.31815593016787913
# Iteration   486; current loss is 0.36136709509538045
# Iteration   487; current loss is 0.3114610851530739
# Iteration   488; current loss is 0.3497495219213268
# Iteration   489; current loss is 0.2263594760317867
# Iteration   490; current loss is 0.3081254715181805
# Iteration   491; current loss is 0.438116397671762
# Iteration   492; current loss is 0.3508781341677379
# Iteration   493; current loss is 0.2775501537541051
# Iteration   494; current loss is 0.3209080745413391
# Iteration   495; current loss is 0.41309880390232845
# Iteration   496; current loss is 0.46522602309428307
# Iteration   497; current loss is 0.2612191756212291
# Iteration   498; current loss is 0.2327690441645418
# Iteration   499; current loss is 0.2041069920737224
# Iteration   500; current loss is 0.28403685749500357
# Iteration   501; current loss is 0.23723652818146831
# Iteration   502; current loss is 0.25804239157474507
# Iteration   503; current loss is 0.3643438924084931
# Iteration   504; current loss is 0.26561940905949033
# Iteration   505; current loss is 0.2755963774584951
# Iteration   506; current loss is 0.16777541773369553
# Iteration   507; current loss is 0.36025027731439124
# Iteration   508; current loss is 0.32717896499576193
# Iteration   509; current loss is 0.2787700112558694
# Iteration   510; current loss is 0.35700443664544346
# Iteration   511; current loss is 0.3378288840212742
# Iteration   512; current loss is 0.35050458034476295
# Iteration   513; current loss is 0.4948574198318169
# Iteration   514; current loss is 0.44651972586112954
# Iteration   515; current loss is 0.27208482723766825
# Iteration   516; current loss is 0.3111719170359727
# Iteration   517; current loss is 0.32602743201450474
# Iteration   518; current loss is 0.28400964311911403
# Iteration   519; current loss is 0.5317539888147443
# Iteration   520; current loss is 0.4549816777609997
# Iteration   521; current loss is 0.3209748746116826
# Iteration   522; current loss is 0.30659738421880534
# Iteration   523; current loss is 0.4476254489005619
# Iteration   524; current loss is 0.40698391044958826
# Iteration   525; current loss is 0.4692638446948887
# Iteration   526; current loss is 0.35121492716568703
# Iteration   527; current loss is 0.2697239978530528
# Iteration   528; current loss is 0.3222619974665244
# Iteration   529; current loss is 0.30087240305056917
# Iteration   530; current loss is 0.3751493825579305
# Iteration   531; current loss is 0.3692804740284238
# Iteration   532; current loss is 0.3743558178558084
# Iteration   533; current loss is 0.33482685368753873
# Iteration   534; current loss is 0.30340297602751115
# Iteration   535; current loss is 0.2816031765880074
# Iteration   536; current loss is 0.27931615418659456
# Iteration   537; current loss is 0.29020836706200387
# Iteration   538; current loss is 0.33890907688892413
# Iteration   539; current loss is 0.2870315149391003
# Iteration   540; current loss is 0.2921956579828382
# Iteration   541; current loss is 0.2328337952378013
# Iteration   542; current loss is 0.27690802612086834
# Iteration   543; current loss is 0.2876952791403207
# Iteration   544; current loss is 0.270076869204657
# Iteration   545; current loss is 0.2339365131814493
# Iteration   546; current loss is 0.33243101101302586
# Iteration   547; current loss is 0.342747407747117
# Iteration   548; current loss is 0.31453423112047985
# Iteration   549; current loss is 0.2387272938600836
# Iteration   550; current loss is 0.2487563164459399
# Iteration   551; current loss is 0.2110012176285324
# Iteration   552; current loss is 0.22395365925183056
# Iteration   553; current loss is 0.3845715013260158
# Iteration   554; current loss is 0.40755278947738593
# Iteration   555; current loss is 0.28855809958545675
# Iteration   556; current loss is 0.3732876361980946
# Iteration   557; current loss is 0.3257163022537204
# Iteration   558; current loss is 0.35369530081211537
# Iteration   559; current loss is 0.2921960825796636
# Iteration   560; current loss is 0.30391029202029207
# Iteration   561; current loss is 0.45702114144949413
# Iteration   562; current loss is 0.4399278570092866
# Iteration   563; current loss is 0.2043812803978577
# Iteration   564; current loss is 0.26471289959684524
# Iteration   565; current loss is 0.2813584342480906
# Iteration   566; current loss is 0.26899340444790104
# Iteration   567; current loss is 0.3088556957706819
# Iteration   568; current loss is 0.2853610826260494
# Iteration   569; current loss is 0.21645988854265916
# Iteration   570; current loss is 0.2744755167777565
# Iteration   571; current loss is 0.34745837749583686
# Iteration   572; current loss is 0.5753778080418289
# Iteration   573; current loss is 0.16853201801231488
# Iteration   574; current loss is 0.40947930522928194
# Iteration   575; current loss is 0.2524538581346754
# Iteration   576; current loss is 0.22859968873827652
# Iteration   577; current loss is 0.41479184053555207
# Iteration   578; current loss is 0.43902857075180945
# Iteration   579; current loss is 0.24626945553061752
# Iteration   580; current loss is 0.3121742795802305
# Iteration   581; current loss is 0.4331286639496449
# Iteration   582; current loss is 0.33180137038358826
# Iteration   583; current loss is 0.32133742724647957
# Iteration   584; current loss is 0.34903814823333335
# Iteration   585; current loss is 0.3443391109257291
# Iteration   586; current loss is 0.39073282115510644
# Iteration   587; current loss is 0.18020771138327535
# Iteration   588; current loss is 0.25100111962525645
# Iteration   589; current loss is 0.3486876868582254
# Iteration   590; current loss is 0.4686187263644335
# Iteration   591; current loss is 0.3395561527183408
# Iteration   592; current loss is 0.3733869576877227
# Iteration   593; current loss is 0.3427521340889881
# Iteration   594; current loss is 0.41784984528704466
# Iteration   595; current loss is 0.3666231805189975
# Iteration   596; current loss is 0.36810814371697664
# Iteration   597; current loss is 0.37155803901785933
# Iteration   598; current loss is 0.4287423317908662
# Iteration   599; current loss is 0.3273572215377234
# Iteration   600; current loss is 0.3116537566444095
# Iteration   601; current loss is 0.361503111807708
# Iteration   602; current loss is 0.2992846816732229
# Iteration   603; current loss is 0.2441703478477355
# Iteration   604; current loss is 0.22618496658311354
# Iteration   605; current loss is 0.20878184418381657
# Iteration   606; current loss is 0.22419187731525902
# Iteration   607; current loss is 0.22689898517643836
# Iteration   608; current loss is 0.32450933969874485
# Iteration   609; current loss is 0.2716738683462183
# Iteration   610; current loss is 0.31225541178474536
# Iteration   611; current loss is 0.1949689739951328
# Iteration   612; current loss is 0.17711657550563165
# Iteration   613; current loss is 0.4706595142896688
# Iteration   614; current loss is 0.4261481358811575
# Iteration   615; current loss is 0.3424179812662037
# Iteration   616; current loss is 0.41576396301233887
# Iteration   617; current loss is 0.30401319667872817
# Iteration   618; current loss is 0.2428693664420678
# Iteration   619; current loss is 0.2448273114461625
# Iteration   620; current loss is 0.19592190277453914
# Iteration   621; current loss is 0.26356876810681434
# Iteration   622; current loss is 0.26574201825819704
# Iteration   623; current loss is 0.27247088909425676
# Iteration   624; current loss is 0.22587992515852193
# Iteration   625; current loss is 0.32615565030371735
# Iteration   626; current loss is 0.3337695075323459
# Iteration   627; current loss is 0.4324555758837002
# Iteration   628; current loss is 0.3810312675909102
# Iteration   629; current loss is 0.29058020997557504
# Iteration   630; current loss is 0.25587279705471677
# Iteration   631; current loss is 0.26085051496068196
# Iteration   632; current loss is 0.25752880597341987
# Iteration   633; current loss is 0.5690399026466415
# Iteration   634; current loss is 0.45096108000937374
# Iteration   635; current loss is 0.30511225176799156
# Iteration   636; current loss is 0.49184530146633626
# Iteration   637; current loss is 0.15216879517077508
# Iteration   638; current loss is 0.254557000079135
# Iteration   639; current loss is 0.3088079303821107
# Iteration   640; current loss is 0.24864737171277274
# Iteration   641; current loss is 0.4102866380340606
# Iteration   642; current loss is 0.41030617511056383
# Iteration   643; current loss is 0.3754269027303263
# Iteration   644; current loss is 0.3272499139028785
# Iteration   645; current loss is 0.3017037803360529
# Iteration   646; current loss is 0.258652003088605
# Iteration   647; current loss is 0.29454961446326877
# Iteration   648; current loss is 0.29227453864705377
# Iteration   649; current loss is 0.34008533448060047
# Iteration   650; current loss is 0.42622162725726176
# Iteration   651; current loss is 0.08113444758586257
# CPU times: user 1min 7s, sys: 4min 21s, total: 5min 28s
# Wall time: 20.7 s

# %%
fig, ax = plt.subplots()
ax.plot(loss_values, label=f"KL Loss")
# plt.ylim(0, 30)
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.set_title(f"Loss Function over Iterations - Alternating Ansatz + KL divergence")
ax.legend()

# fig.savefig("loss_curve.png")

# %%
def compute_fidelity(psi, phi):
    """
    Compute the fidelity (a measure of similarity) between the two states
    :param psi: qiskit.Statevector, our target state |psi>
    :param phi: qiskit.Statevector, our estimated state |phi>
    :return: float, fidelity
    """

    fidelity = qiskit.quantum_info.state_fidelity(psi, phi)
    print(f"psi: {psi}, phi: {phi}")
    # fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    # plot_bloch_multivector(psi)
    # axes[0].set_title("psi")
    # plot_bloch_multivector(phi)
    # axes[1].set_title("phi")
    return fidelity



ansatz_state = Statevector.from_instruction(ansatz.assign_parameters({param_vec : results.x}))

final_fidelity = qiskit.quantum_info.state_fidelity(gs_state, ansatz_state)

# %%
print(f"target state: {gs_state}\nansatz: {ansatz_state}")
# Out:
# target state: Statevector([ 0.        +0.j,  0.        +0.j,  0.        +0.j,
#              -0.40824829+0.j,  0.        +0.j,  0.81649658+0.j,
#              -0.40824829+0.j,  0.        +0.j],
#             dims=(2, 2, 2))
# ansatz: Statevector([ 1.23224254e-02+0.01266409j,  1.98218857e-02-0.02750175j,
#              -9.83352146e-03-0.01463591j,  3.40355852e-01-0.23244651j,
#              -4.31048444e-04+0.01101474j, -4.73250154e-01+0.63494665j,
#               3.97018456e-01-0.20727552j, -1.50825423e-02-0.01718669j],
#             dims=(2, 2, 2))

# %%
print(final_fidelity)
# Out:
# 0.9597030517116788

# %%
print(results.x)
# Out:
# [-1.46996859  1.04046776 -0.25284869 -0.81781515  3.16612369  1.00966992
#   0.3768499   1.14283377  0.47149562 -1.00244719  0.11197392 -0.86176522
#   0.50212617  0.86790873  0.18951971  1.46828678 -0.29259106  1.10610971
#  -0.15065687 -0.76387401  0.11839122  0.63655647  1.01828537  0.51600406
#   0.76177743 -2.38941258  1.59649283 -1.76592282 -0.2580067  -0.41883785]

# %%
np.save(f"saved/params_training_s{trial}.npy", thetas)
np.save(f"saved/loss_training_s{trial}.npy", loss_values)
np.save(f"saved/final_theta_s{trial}.npy", results.x)
np.save(f"saved/fidelity_s{trial}.npy", final_fidelity)
